# %%
# !which pip
# Out:
# /Users/bytedance/miniconda3/envs/agent/bin/pip

# %%
# !echo $GITHUB_TOKEN
# Out:
# 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

# %% [markdown]
# # 获取 GitHub 项目进展
#
# 以下代码主要由 GPT-4 生成，演示 `GitHubClient` 模块的版本演进。
#
#
# ## 使用 GitHub REST API 获取项目信息
#
# GitHub REST API 为开发者提供了便捷获取 GitHub 项目的丰富 API。
#
# ![Github Docs](images/github_docs.png)
#
# 例如，获取项目 issues 列表，GitHub 提供了 `"List repository issues"` API。
#
#
# ## GitHub Token 配置
#
# 使用 `GitHubClient` 模块调用 GitHub REST API 需要配置 [GitHub Fine-grained personal access token](https://github.com/settings/tokens?type=beta)。
#
# - **配置文件**：正式启动 GitHubSentinel 项目，可以替换 `config.json` 中 `github_token` 值。
# - **Jupyter测试**：在使用构造函数实例化 GitHubClient 类，以参数形式传入。
#
# 下面以 https://github.com/langchain-ai/langchain 项目为例，演示 GitHubClient 使用方法

# %% [markdown]
# ## [v0.2] GitHubClient Class

# %%
# src/github_client.py

import requests  # 导入requests库用于发起HTTP请求
import datetime  # 导入datetime库处理日期和时间

class GitHubClient:
    def __init__(self, token):
        self.token = token  # GitHub的访问令牌
        # 初始化请求头部，这里主要是为了使用GitHub的API进行身份验证
        self.headers = {'Authorization': f'token {self.token}'}

    def fetch_updates(self, repos):
        # 为给定的仓库列表获取更新，包括提交、问题和拉取请求
        updates = {}
        for repo in repos:
            # 遍历每个仓库并获取相关信息
            updates[repo] = {
                'commits': self.fetch_commits(repo),  # 获取提交记录
                'issues': self.fetch_issues(repo),   # 获取问题
                'pull_requests': self.fetch_pull_requests(repo)  # 获取拉取请求
            }
        return updates

    def fetch_commits(self, repo):
        # 构建获取提交记录的API URL
        url = f'https://api.github.com/repos/{repo}/commits'
        response = requests.get(url, headers=self.headers)
        response.raise_for_status()  # 检查请求是否成功，如果出错则抛出异常
        return response.json()  # 返回解析JSON格式的数据

    def fetch_issues(self, repo):
        # 构建获取问题(issue)的API URL
        url = f'https://api.github.com/repos/{repo}/issues'
        response = requests.get(url, headers=self.headers)
        response.raise_for_status()  # 确保响应没有HTTP错误
        return response.json()  # 返回JSON数据

    def fetch_pull_requests(self, repo):
        # 构建获取拉取请求(pull requests)的API URL
        url = f'https://api.github.com/repos/{repo}/pulls'
        response = requests.get(url, headers=self.headers)
        response.raise_for_status()
        return response.json()  # 返回JSON格式的拉取请求数据

    def export_daily_progress(self, repo):
        # 导出指定仓库的每日进度，包括问题和拉取请求
        date_str = datetime.datetime.now().strftime('%Y-%m-%d')  # 获取当前日期字符串
        issues = self.fetch_issues(repo)  # 获取当天的问题
        pull_requests = self.fetch_pull_requests(repo)  # 获取当天的拉取请求
        filename = f"{repo.replace('/', '_')}_{date_str}.md"  # 根据仓库名和日期生成文件名

        # 打开文件进行写入
        with open(filename, 'w') as f:
            f.write(f"# {repo} Daily Progress - {date_str}\n\n")  # 写入标题
            f.write("## Issues\n")
            for issue in issues:
                f.write(f"- {issue['title']} #{issue['number']}\n")  # 列出每个问题
            f.write("\n## Pull Requests\n")
            for pr in pull_requests:
                f.write(f"- {pr['title']} #{pr['number']}\n")  # 列出每个拉取请求

        print(f"Exported daily progress to {filename}")  # 打印导出信息

        return filename

# %% [markdown]
# ### 实例化 GitHubClient
#
# 从环境变量中获取 `GITHUB_TOKEN`，依次获取 Commits, Issues 和 Pull Requests。

# %%
import os

github_client = GitHubClient(token=os.getenv("GITHUB_TOKEN"))

# %% [markdown]
# ### List Issues API
#
# API完整文档说明见：https://docs.github.com/en/rest/issues/issues?apiVersion=2022-11-28#list-repository-issues
#
# **请求样例**：`GET /repos/{owner}/{repo}/issues`;
#
# **返回样例**：
#
# ```json
# [
#   {
#     "id": 1,
#     "node_id": "MDU6SXNzdWUx",
#     "url": "https://api.github.com/repos/octocat/Hello-World/issues/1347",
#     "repository_url": "https://api.github.com/repos/octocat/Hello-World",
#     "labels_url": "https://api.github.com/repos/octocat/Hello-World/issues/1347/labels{/name}",
#     "comments_url": "https://api.github.com/repos/octocat/Hello-World/issues/1347/comments",
#     "events_url": "https://api.github.com/repos/octocat/Hello-World/issues/1347/events",
#     "html_url": "https://github.com/octocat/Hello-World/issues/1347",
#     "number": 1347,
#     "state": "open",
#     "title": "Found a bug",
#     "body": "I'm having a problem with this.",
#     "user": {
#       "login": "octocat",
#       "id": 1,
#       "node_id": "MDQ6VXNlcjE=",
#       "avatar_url": "https://github.com/images/error/octocat_happy.gif",
#       "gravatar_id": "",
#       "url": "https://api.github.com/users/octocat",
#       "html_url": "https://github.com/octocat",
#       "followers_url": "https://api.github.com/users/octocat/followers",
#       "following_url": "https://api.github.com/users/octocat/following{/other_user}",
#       "gists_url": "https://api.github.com/users/octocat/gists{/gist_id}",
#       "starred_url": "https://api.github.com/users/octocat/starred{/owner}{/repo}",
#       "subscriptions_url": "https://api.github.com/users/octocat/subscriptions",
#       "organizations_url": "https://api.github.com/users/octocat/orgs",
#       "repos_url": "https://api.github.com/users/octocat/repos",
#       "events_url": "https://api.github.com/users/octocat/events{/privacy}",
#       "received_events_url": "https://api.github.com/users/octocat/received_events",
#       "type": "User",
#       "site_admin": false
#     },
#     "labels": [
#       {
#         "id": 208045946,
#         "node_id": "MDU6TGFiZWwyMDgwNDU5NDY=",
#         "url": "https://api.github.com/repos/octocat/Hello-World/labels/bug",
#         "name": "bug",
#         "description": "Something isn't working",
#         "color": "f29513",
#         "default": true
#       }
#     ],
#     "assignee": {
#       "login": "octocat",
#       "id": 1,
#       "node_id": "MDQ6VXNlcjE=",
#       "avatar_url": "https://github.com/images/error/octocat_happy.gif",
#       "gravatar_id": "",
#       "url": "https://api.github.com/users/octocat",
#       "html_url": "https://github.com/octocat",
#       "followers_url": "https://api.github.com/users/octocat/followers",
#       "following_url": "https://api.github.com/users/octocat/following{/other_user}",
#       "gists_url": "https://api.github.com/users/octocat/gists{/gist_id}",
#       "starred_url": "https://api.github.com/users/octocat/starred{/owner}{/repo}",
#       "subscriptions_url": "https://api.github.com/users/octocat/subscriptions",
#       "organizations_url": "https://api.github.com/users/octocat/orgs",
#       "repos_url": "https://api.github.com/users/octocat/repos",
#       "events_url": "https://api.github.com/users/octocat/events{/privacy}",
#       "received_events_url": "https://api.github.com/users/octocat/received_events",
#       "type": "User",
#       "site_admin": false
#     },
#     "assignees": [
#       {
#         "login": "octocat",
#         "id": 1,
#         "node_id": "MDQ6VXNlcjE=",
#         "avatar_url": "https://github.com/images/error/octocat_happy.gif",
#         "gravatar_id": "",
#         "url": "https://api.github.com/users/octocat",
#         "html_url": "https://github.com/octocat",
#         "followers_url": "https://api.github.com/users/octocat/followers",
#         "following_url": "https://api.github.com/users/octocat/following{/other_user}",
#         "gists_url": "https://api.github.com/users/octocat/gists{/gist_id}",
#         "starred_url": "https://api.github.com/users/octocat/starred{/owner}{/repo}",
#         "subscriptions_url": "https://api.github.com/users/octocat/subscriptions",
#         "organizations_url": "https://api.github.com/users/octocat/orgs",
#         "repos_url": "https://api.github.com/users/octocat/repos",
#         "events_url": "https://api.github.com/users/octocat/events{/privacy}",
#         "received_events_url": "https://api.github.com/users/octocat/received_events",
#         "type": "User",
#         "site_admin": false
#       }
#     ],
#     "milestone": {
#       "url": "https://api.github.com/repos/octocat/Hello-World/milestones/1",
#       "html_url": "https://github.com/octocat/Hello-World/milestones/v1.0",
#       "labels_url": "https://api.github.com/repos/octocat/Hello-World/milestones/1/labels",
#       "id": 1002604,
#       "node_id": "MDk6TWlsZXN0b25lMTAwMjYwNA==",
#       "number": 1,
#       "state": "open",
#       "title": "v1.0",
#       "description": "Tracking milestone for version 1.0",
#       "creator": {
#         "login": "octocat",
#         "id": 1,
#         "node_id": "MDQ6VXNlcjE=",
#         "avatar_url": "https://github.com/images/error/octocat_happy.gif",
#         "gravatar_id": "",
#         "url": "https://api.github.com/users/octocat",
#         "html_url": "https://github.com/octocat",
#         "followers_url": "https://api.github.com/users/octocat/followers",
#         "following_url": "https://api.github.com/users/octocat/following{/other_user}",
#         "gists_url": "https://api.github.com/users/octocat/gists{/gist_id}",
#         "starred_url": "https://api.github.com/users/octocat/starred{/owner}{/repo}",
#         "subscriptions_url": "https://api.github.com/users/octocat/subscriptions",
#         "organizations_url": "https://api.github.com/users/octocat/orgs",
#         "repos_url": "https://api.github.com/users/octocat/repos",
#         "events_url": "https://api.github.com/users/octocat/events{/privacy}",
#         "received_events_url": "https://api.github.com/users/octocat/received_events",
#         "type": "User",
#         "site_admin": false
#       },
#       "open_issues": 4,
#       "closed_issues": 8,
#       "created_at": "2011-04-10T20:09:31Z",
#       "updated_at": "2014-03-03T18:58:10Z",
#       "closed_at": "2013-02-12T13:22:01Z",
#       "due_on": "2012-10-09T23:39:01Z"
#     },
#     "locked": true,
#     "active_lock_reason": "too heated",
#     "comments": 0,
#     "pull_request": {
#       "url": "https://api.github.com/repos/octocat/Hello-World/pulls/1347",
#       "html_url": "https://github.com/octocat/Hello-World/pull/1347",
#       "diff_url": "https://github.com/octocat/Hello-World/pull/1347.diff",
#       "patch_url": "https://github.com/octocat/Hello-World/pull/1347.patch"
#     },
#     "closed_at": null,
#     "created_at": "2011-04-22T13:33:48Z",
#     "updated_at": "2011-04-22T13:33:48Z",
#     "closed_by": {
#       "login": "octocat",
#       "id": 1,
#       "node_id": "MDQ6VXNlcjE=",
#       "avatar_url": "https://github.com/images/error/octocat_happy.gif",
#       "gravatar_id": "",
#       "url": "https://api.github.com/users/octocat",
#       "html_url": "https://github.com/octocat",
#       "followers_url": "https://api.github.com/users/octocat/followers",
#       "following_url": "https://api.github.com/users/octocat/following{/other_user}",
#       "gists_url": "https://api.github.com/users/octocat/gists{/gist_id}",
#       "starred_url": "https://api.github.com/users/octocat/starred{/owner}{/repo}",
#       "subscriptions_url": "https://api.github.com/users/octocat/subscriptions",
#       "organizations_url": "https://api.github.com/users/octocat/orgs",
#       "repos_url": "https://api.github.com/users/octocat/repos",
#       "events_url": "https://api.github.com/users/octocat/events{/privacy}",
#       "received_events_url": "https://api.github.com/users/octocat/received_events",
#       "type": "User",
#       "site_admin": false
#     },
#     "author_association": "COLLABORATOR",
#     "state_reason": "completed"
#   }
# ]
# ```

# %%
repo = "langchain-ai/langchain"

# %%
issues = github_client.fetch_issues(repo)

# %% [markdown]
# ### GitHubClient fetch 方法 repo 参数格式要求
#
# 从 GitHub 获取项目进展，需要访问形如 `https://api.github.com/repos/{repo}/issues`(以issues为例）的 URL。因此，repo 必须符合 GitHub Repo 标准命名，如下所示:
#
# ```json
# [
#     "langchain-ai/langchain",
#     "DjangoPeng/openai-quickstart",
#     "ollama/ollama"
# ]
# ```
#
# **GitHubSentinel 项目订阅管理配置文件为 `subscriptions.json`。**

# %%
issues
# Out:
# [{'url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25729',
#   'repository_url': 'https://api.github.com/repos/langchain-ai/langchain',
#   'labels_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25729/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25729/comments',
#   'events_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25729/events',
#   'html_url': 'https://github.com/langchain-ai/langchain/pull/25729',
#   'id': 2484915642,
#   'node_id': 'PR_kwDOIPDwls55VuRm',
#   'number': 25729,
#   'title': 'core[patch]: Release 0.2.35',
#   'user': {'login': 'baskaryan',
#    'id': 22008038,
#    'node_id': 'MDQ6VXNlcjIyMDA4MDM4',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/22008038?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/baskaryan',
#    'html_url': 'https://github.com/baskaryan',
#    'followers_url': 'https://api.github.com/users/baskaryan/followers',
#    'following_url': 'https://api.github.com/users/baskaryan/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/baskaryan/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/baskaryan/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/baskaryan/subscriptions',
#    'organizations_url': 'https://api.github.com/users/baskaryan/orgs',
#    'repos_url': 'https://api.github.com/users/baskaryan/repos',
#    'events_url': 'https://api.github.com/users/baskaryan/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/baskaryan/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 6232714104,
#     'node_id': 'LA_kwDOIPDwls8AAAABc3-reA',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/size:XS',
#     'name': 'size:XS',
#     'color': 'C2E0C6',
#     'default': False,
#     'description': 'This PR changes 0-9 lines, ignoring generated files.'},
#    {'id': 6467902041,
#     'node_id': 'LA_kwDOIPDwls8AAAABgYRaWQ',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/%F0%9F%A4%96:release',
#     'name': '🤖:release',
#     'color': 'C5DEF5',
#     'default': False,
#     'description': 'Bumping package version for release'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2024-08-24T23:07:38Z',
#   'updated_at': '2024-08-24T23:08:07Z',
#   'closed_at': None,
#   'author_association': 'COLLABORATOR',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/langchain-ai/langchain/pulls/25729',
#    'html_url': 'https://github.com/langchain-ai/langchain/pull/25729',
#    'diff_url': 'https://github.com/langchain-ai/langchain/pull/25729.diff',
#    'patch_url': 'https://github.com/langchain-ai/langchain/pull/25729.patch',
#    'merged_at': None},
#   'body': None,
#   'reactions': {'url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25729/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25729/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25728',
#   'repository_url': 'https://api.github.com/repos/langchain-ai/langchain',
#   'labels_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25728/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25728/comments',
#   'events_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25728/events',
#   'html_url': 'https://github.com/langchain-ai/langchain/pull/25728',
#   'id': 2484914653,
#   'node_id': 'PR_kwDOIPDwls55VuGE',
#   'number': 25728,
#   'title': 'community: Minor Improvement of extract hyperlinks tool output',
#   'user': {'login': 'zysoong',
#    'id': 75294755,
#    'node_id': 'MDQ6VXNlcjc1Mjk0NzU1',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/75294755?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/zysoong',
#    'html_url': 'https://github.com/zysoong',
#    'followers_url': 'https://api.github.com/users/zysoong/followers',
#    'following_url': 'https://api.github.com/users/zysoong/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/zysoong/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/zysoong/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/zysoong/subscriptions',
#    'organizations_url': 'https://api.github.com/users/zysoong/orgs',
#    'repos_url': 'https://api.github.com/users/zysoong/repos',
#    'events_url': 'https://api.github.com/users/zysoong/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/zysoong/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 5680700883,
#     'node_id': 'LA_kwDOIPDwls8AAAABUpid0w',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/%F0%9F%A4%96:nit',
#     'name': '🤖:nit',
#     'color': 'C5DEF5',
#     'default': False,
#     'description': 'Small modifications/deletions, fixes, deps or improvements to existing code or docs'},
#    {'id': 6232714104,
#     'node_id': 'LA_kwDOIPDwls8AAAABc3-reA',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/size:XS',
#     'name': 'size:XS',
#     'color': 'C2E0C6',
#     'default': False,
#     'description': 'This PR changes 0-9 lines, ignoring generated files.'},
#    {'id': 7097373342,
#     'node_id': 'LA_kwDOIPDwls8AAAABpwlSng',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/community',
#     'name': 'community',
#     'color': '579082',
#     'default': False,
#     'description': 'Related to langchain-community'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2024-08-24T23:04:44Z',
#   'updated_at': '2024-08-24T23:20:38Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/langchain-ai/langchain/pulls/25728',
#    'html_url': 'https://github.com/langchain-ai/langchain/pull/25728',
#    'diff_url': 'https://github.com/langchain-ai/langchain/pull/25728.diff',
#    'patch_url': 'https://github.com/langchain-ai/langchain/pull/25728.patch',
#    'merged_at': None},
#   'body': "**Description:** Make the hyperlink only appear once in the extract_hyperlinks tool output. (for some websites output contains meaningless '#' hyperlinks multiple times which will extend the tokens of context window without any advantage)\r\n**Issue:** None\r\n**Dependencies:** None\r\n",
#   'reactions': {'url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25728/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25728/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25727',
#   'repository_url': 'https://api.github.com/repos/langchain-ai/langchain',
#   'labels_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25727/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25727/comments',
#   'events_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25727/events',
#   'html_url': 'https://github.com/langchain-ai/langchain/pull/25727',
#   'id': 2484863143,
#   'node_id': 'PR_kwDOIPDwls55VjjN',
#   'number': 25727,
#   'title': 'community: fix model initialization bug for deepinfra',
#   'user': {'login': 'mo374z',
#    'id': 87517800,
#    'node_id': 'MDQ6VXNlcjg3NTE3ODAw',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/87517800?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mo374z',
#    'html_url': 'https://github.com/mo374z',
#    'followers_url': 'https://api.github.com/users/mo374z/followers',
#    'following_url': 'https://api.github.com/users/mo374z/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/mo374z/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/mo374z/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/mo374z/subscriptions',
#    'organizations_url': 'https://api.github.com/users/mo374z/orgs',
#    'repos_url': 'https://api.github.com/users/mo374z/repos',
#    'events_url': 'https://api.github.com/users/mo374z/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/mo374z/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 5680700839,
#     'node_id': 'LA_kwDOIPDwls8AAAABUpidpw',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/%F0%9F%A4%96:bug',
#     'name': '🤖:bug',
#     'color': 'F9D0C4',
#     'default': False,
#     'description': 'Related to a bug, vulnerability, unexpected error with an existing feature'},
#    {'id': 6232714104,
#     'node_id': 'LA_kwDOIPDwls8AAAABc3-reA',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/size:XS',
#     'name': 'size:XS',
#     'color': 'C2E0C6',
#     'default': False,
#     'description': 'This PR changes 0-9 lines, ignoring generated files.'},
#    {'id': 7097373342,
#     'node_id': 'LA_kwDOIPDwls8AAAABpwlSng',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/community',
#     'name': 'community',
#     'color': '579082',
#     'default': False,
#     'description': 'Related to langchain-community'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2024-08-24T21:01:08Z',
#   'updated_at': '2024-08-24T21:11:55Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/langchain-ai/langchain/pulls/25727',
#    'html_url': 'https://github.com/langchain-ai/langchain/pull/25727',
#    'diff_url': 'https://github.com/langchain-ai/langchain/pull/25727.diff',
#    'patch_url': 'https://github.com/langchain-ai/langchain/pull/25727.patch',
#    'merged_at': None},
#   'body': '### Description\r\nadds an init method to ChatDeepInfra to set the model_name attribute accordings to the argument\r\n### Issue\r\ncurrently, the model_name specified by the user during initialization of the ChatDeepInfra class is never set. Therefore, it always chooses the default model (meta-llama/Llama-2-70b-chat-hf, however probably since this is deprecated it always uses meta-llama/Llama-3-70b-Instruct). We stumbled across this issue and fixed it as proposed in this pull request. Feel free to change the fix according to your coding guidelines and style, this is just a proposal and we want to draw attention to this problem.\r\n### Dependencies\r\nno additional dependencies required\r\n\r\nFeel free to contact me or @timo282 and @finitearth if you have any questions.',
#   'reactions': {'url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25727/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25727/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25726',
#   'repository_url': 'https://api.github.com/repos/langchain-ai/langchain',
#   'labels_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25726/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25726/comments',
#   'events_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25726/events',
#   'html_url': 'https://github.com/langchain-ai/langchain/pull/25726',
#   'id': 2484679801,
#   'node_id': 'PR_kwDOIPDwls55U9jR',
#   'number': 25726,
#   'title': 'mongodb : update MongoDBChatMessageHistory to accept existing mongo_client',
#   'user': {'login': 'SuperMuel',
#    'id': 69467005,
#    'node_id': 'MDQ6VXNlcjY5NDY3MDA1',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/69467005?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/SuperMuel',
#    'html_url': 'https://github.com/SuperMuel',
#    'followers_url': 'https://api.github.com/users/SuperMuel/followers',
#    'following_url': 'https://api.github.com/users/SuperMuel/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/SuperMuel/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/SuperMuel/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/SuperMuel/subscriptions',
#    'organizations_url': 'https://api.github.com/users/SuperMuel/orgs',
#    'repos_url': 'https://api.github.com/users/SuperMuel/repos',
#    'events_url': 'https://api.github.com/users/SuperMuel/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/SuperMuel/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 5680700883,
#     'node_id': 'LA_kwDOIPDwls8AAAABUpid0w',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/%F0%9F%A4%96:nit',
#     'name': '🤖:nit',
#     'color': 'C5DEF5',
#     'default': False,
#     'description': 'Small modifications/deletions, fixes, deps or improvements to existing code or docs'},
#    {'id': 6232714108,
#     'node_id': 'LA_kwDOIPDwls8AAAABc3-rfA',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/size:S',
#     'name': 'size:S',
#     'color': 'BFDADC',
#     'default': False,
#     'description': 'This PR changes 10-29 lines, ignoring generated files.'},
#    {'id': 6348691034,
#     'node_id': 'LA_kwDOIPDwls8AAAABemlWWg',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/partner',
#     'name': 'partner',
#     'color': 'ededed',
#     'default': False,
#     'description': None}],
#   'state': 'open',
#   'locked': False,
#   'assignee': {'login': 'efriis',
#    'id': 9557659,
#    'node_id': 'MDQ6VXNlcjk1NTc2NTk=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/9557659?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/efriis',
#    'html_url': 'https://github.com/efriis',
#    'followers_url': 'https://api.github.com/users/efriis/followers',
#    'following_url': 'https://api.github.com/users/efriis/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/efriis/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/efriis/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/efriis/subscriptions',
#    'organizations_url': 'https://api.github.com/users/efriis/orgs',
#    'repos_url': 'https://api.github.com/users/efriis/repos',
#    'events_url': 'https://api.github.com/users/efriis/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/efriis/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'assignees': [{'login': 'efriis',
#     'id': 9557659,
#     'node_id': 'MDQ6VXNlcjk1NTc2NTk=',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/9557659?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/efriis',
#     'html_url': 'https://github.com/efriis',
#     'followers_url': 'https://api.github.com/users/efriis/followers',
#     'following_url': 'https://api.github.com/users/efriis/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/efriis/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/efriis/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/efriis/subscriptions',
#     'organizations_url': 'https://api.github.com/users/efriis/orgs',
#     'repos_url': 'https://api.github.com/users/efriis/repos',
#     'events_url': 'https://api.github.com/users/efriis/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/efriis/received_events',
#     'type': 'User',
#     'site_admin': False}],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2024-08-24T15:44:10Z',
#   'updated_at': '2024-08-24T15:59:27Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/langchain-ai/langchain/pulls/25726',
#    'html_url': 'https://github.com/langchain-ai/langchain/pull/25726',
#    'diff_url': 'https://github.com/langchain-ai/langchain/pull/25726.diff',
#    'patch_url': 'https://github.com/langchain-ai/langchain/pull/25726.patch',
#    'merged_at': None},
#   'body': '### Description\r\n\r\nThis PR enhances the `MongoDBChatMessageHistory` class by adding support for initialization with an existing `MongoClient` instance.\r\n\r\n#### Benefits:\r\n- **Custom Configurations:** Allows the use of a `MongoClient` instance with specific configurations.\r\n- **Performance Improvement:** Enhances performance by preventing the repeated creation of new `MongoClient` instances for each session, thereby eliminating the need for re-authentication on every new session.\r\n\r\n#### Instantiation with a `connection_string` (current method):\r\n```python\r\nfrom langchain_mongodb import MongoDBChatMessageHistory\r\n\r\nhistory = MongoDBChatMessageHistory(\r\n    connection_string="mongodb://your-host:your-port/",\r\n    session_id="your-session-id",\r\n)\r\n```\r\n\r\n#### Instantiation with an existing `MongoClient` (new feature in this PR):\r\n```python\r\nfrom langchain_mongodb import MongoDBChatMessageHistory\r\nfrom pymongo import MongoClient\r\n\r\nexisting_client = MongoClient("mongodb://your-host:your-port/")\r\nhistory2 = MongoDBChatMessageHistory(\r\n    connection_string=None,\r\n    session_id="your-session-id",\r\n    client=existing_client,\r\n)\r\n```\r\n\r\n**Note:**  \r\nDue to the existing parameter order where `connection_string` precedes `session_id`, and since `session_id` does not (and should not) have a default value, I think it’s not possible to set a default value of `None` for `connection_string`. Changing the order of these parameters would introduce breaking changes.',
#   'reactions': {'url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25726/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25726/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25725',
#   'repository_url': 'https://api.github.com/repos/langchain-ai/langchain',
#   'labels_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25725/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25725/comments',
#   'events_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25725/events',
#   'html_url': 'https://github.com/langchain-ai/langchain/pull/25725',
#   'id': 2484674808,
#   'node_id': 'PR_kwDOIPDwls55U8jC',
#   'number': 25725,
#   'title': 'Update endpoint for AzureMLEndpointApiType class.',
#   'user': {'login': 'ashvin-a',
#    'id': 88977094,
#    'node_id': 'MDQ6VXNlcjg4OTc3MDk0',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/88977094?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ashvin-a',
#    'html_url': 'https://github.com/ashvin-a',
#    'followers_url': 'https://api.github.com/users/ashvin-a/followers',
#    'following_url': 'https://api.github.com/users/ashvin-a/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/ashvin-a/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/ashvin-a/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/ashvin-a/subscriptions',
#    'organizations_url': 'https://api.github.com/users/ashvin-a/orgs',
#    'repos_url': 'https://api.github.com/users/ashvin-a/repos',
#    'events_url': 'https://api.github.com/users/ashvin-a/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/ashvin-a/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 6232714108,
#     'node_id': 'LA_kwDOIPDwls8AAAABc3-rfA',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/size:S',
#     'name': 'size:S',
#     'color': 'BFDADC',
#     'default': False,
#     'description': 'This PR changes 10-29 lines, ignoring generated files.'},
#    {'id': 7097373342,
#     'node_id': 'LA_kwDOIPDwls8AAAABpwlSng',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/community',
#     'name': 'community',
#     'color': '579082',
#     'default': False,
#     'description': 'Related to langchain-community'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2024-08-24T15:34:41Z',
#   'updated_at': '2024-08-24T15:37:27Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/langchain-ai/langchain/pulls/25725',
#    'html_url': 'https://github.com/langchain-ai/langchain/pull/25725',
#    'diff_url': 'https://github.com/langchain-ai/langchain/pull/25725.diff',
#    'patch_url': 'https://github.com/langchain-ai/langchain/pull/25725.patch',
#    'merged_at': None},
#   'body': 'This addresses the issue mentioned in #25702\r\n\r\nI have updated the endpoint used in validating the endpoint API type in the AzureMLBaseEndpoint class from `/v1/completions` to `/completions` and `/v1/chat/completions` to `/chat/completions`.',
#   'reactions': {'url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25725/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25725/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25722',
#   'repository_url': 'https://api.github.com/repos/langchain-ai/langchain',
#   'labels_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25722/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25722/comments',
#   'events_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25722/events',
#   'html_url': 'https://github.com/langchain-ai/langchain/issues/25722',
#   'id': 2484287262,
#   'node_id': 'I_kwDOIPDwls6UEzce',
#   'number': 25722,
#   'title': 'Crash and retreat （崩溃，闪退）',
#   'user': {'login': 'lishaozheng',
#    'id': 82505377,
#    'node_id': 'MDQ6VXNlcjgyNTA1Mzc3',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/82505377?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/lishaozheng',
#    'html_url': 'https://github.com/lishaozheng',
#    'followers_url': 'https://api.github.com/users/lishaozheng/followers',
#    'following_url': 'https://api.github.com/users/lishaozheng/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/lishaozheng/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/lishaozheng/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/lishaozheng/subscriptions',
#    'organizations_url': 'https://api.github.com/users/lishaozheng/orgs',
#    'repos_url': 'https://api.github.com/users/lishaozheng/repos',
#    'events_url': 'https://api.github.com/users/lishaozheng/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/lishaozheng/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 5541432778,
#     'node_id': 'LA_kwDOIPDwls8AAAABSkuNyg',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/%E2%B1%AD:%20vector%20store',
#     'name': 'Ɑ: vector store',
#     'color': 'D4C5F9',
#     'default': False,
#     'description': 'Related to vector store module'},
#    {'id': 5680700839,
#     'node_id': 'LA_kwDOIPDwls8AAAABUpidpw',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/%F0%9F%A4%96:bug',
#     'name': '🤖:bug',
#     'color': 'F9D0C4',
#     'default': False,
#     'description': 'Related to a bug, vulnerability, unexpected error with an existing feature'},
#    {'id': 5924999838,
#     'node_id': 'LA_kwDOIPDwls8AAAABYShSng',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/%F0%9F%94%8C:%20chroma',
#     'name': '🔌: chroma',
#     'color': 'BFD4F2',
#     'default': False,
#     'description': 'Primarily related to ChromaDB integrations'},
#    {'id': 6411661606,
#     'node_id': 'LA_kwDOIPDwls8AAAABfioxJg',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/investigate',
#     'name': 'investigate',
#     'color': '4D8397',
#     'default': False,
#     'description': ''}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2024-08-24T06:29:20Z',
#   'updated_at': '2024-08-24T06:32:17Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': '### Checked other resources\n\n- [X] I added a very descriptive title to this issue.\n- [X] I searched the LangChain documentation with the integrated search.\n- [X] I used the GitHub search to find a similar question and didn\'t find it.\n- [X] I am sure that this is a bug in LangChain rather than my code.\n- [X] The bug is not resolved by updating to the latest stable version of LangChain (or the specific integration package).\n\n### Example Code\n\nfor iteration, text in enumerate(response_list):\r\n                if 0 <= iteration < 6:\r\n                    t = text\r\n                    # 记录 泛化后的问题\r\n                    if t:\r\n                        logger_gpt.info(f" {conversion_name} get_vectordb_docs檢索問題：“{t}”")\r\n                        # 是不是檢索產品庫\r\n                        product_result.append(\r\n                            self.executor.submit(\r\n                                product_docsearchs[iteration].similarity_search_with_score,\r\n                                query=t, k=2))\r\n                        script_result.append(\r\n                            self.executor.submit(\r\n                                script_docsearchs[iteration].similarity_search_with_score,\r\n                                query=t, k=2))\n\n### Error Message and Stack Trace (if applicable)\n\n![image](https://github.com/user-attachments/assets/8090509f-ada8-4695-9cc0-5a2c8e7aa05e)\r\n\n\n### Description\n\n\r\n持久化二十个本地向量数据库，然后实例化二十个Chroma，并发同时调用similarity_search_with_score，就出现的（崩溃，闪退）\r\n\r\nPersist 20 local vector databases, then instantiate 20 Chromas, and call similarity_search_with_score at the same time.\n\n### System Info\n\npip install  Chromadb-0.5.5',
#   'reactions': {'url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25722/reactions',
#    'total_count': 1,
#    '+1': 1,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25722/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25721',
#   'repository_url': 'https://api.github.com/repos/langchain-ai/langchain',
#   'labels_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25721/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25721/comments',
#   'events_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25721/events',
#   'html_url': 'https://github.com/langchain-ai/langchain/pull/25721',
#   'id': 2484100189,
#   'node_id': 'PR_kwDOIPDwls55TDJC',
#   'number': 25721,
#   'title': 'all: more lint additions',
#   'user': {'login': 'efriis',
#    'id': 9557659,
#    'node_id': 'MDQ6VXNlcjk1NTc2NTk=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/9557659?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/efriis',
#    'html_url': 'https://github.com/efriis',
#    'followers_url': 'https://api.github.com/users/efriis/followers',
#    'following_url': 'https://api.github.com/users/efriis/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/efriis/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/efriis/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/efriis/subscriptions',
#    'organizations_url': 'https://api.github.com/users/efriis/orgs',
#    'repos_url': 'https://api.github.com/users/efriis/repos',
#    'events_url': 'https://api.github.com/users/efriis/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/efriis/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 5680700883,
#     'node_id': 'LA_kwDOIPDwls8AAAABUpid0w',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/%F0%9F%A4%96:nit',
#     'name': '🤖:nit',
#     'color': 'C5DEF5',
#     'default': False,
#     'description': 'Small modifications/deletions, fixes, deps or improvements to existing code or docs'},
#    {'id': 6232714119,
#     'node_id': 'LA_kwDOIPDwls8AAAABc3-rhw',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/size:M',
#     'name': 'size:M',
#     'color': 'FEF2C0',
#     'default': False,
#     'description': 'This PR changes 30-99 lines, ignoring generated files.'},
#    {'id': 6348691034,
#     'node_id': 'LA_kwDOIPDwls8AAAABemlWWg',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/partner',
#     'name': 'partner',
#     'color': 'ededed',
#     'default': False,
#     'description': None}],
#   'state': 'open',
#   'locked': False,
#   'assignee': {'login': 'efriis',
#    'id': 9557659,
#    'node_id': 'MDQ6VXNlcjk1NTc2NTk=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/9557659?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/efriis',
#    'html_url': 'https://github.com/efriis',
#    'followers_url': 'https://api.github.com/users/efriis/followers',
#    'following_url': 'https://api.github.com/users/efriis/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/efriis/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/efriis/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/efriis/subscriptions',
#    'organizations_url': 'https://api.github.com/users/efriis/orgs',
#    'repos_url': 'https://api.github.com/users/efriis/repos',
#    'events_url': 'https://api.github.com/users/efriis/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/efriis/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'assignees': [{'login': 'efriis',
#     'id': 9557659,
#     'node_id': 'MDQ6VXNlcjk1NTc2NTk=',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/9557659?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/efriis',
#     'html_url': 'https://github.com/efriis',
#     'followers_url': 'https://api.github.com/users/efriis/followers',
#     'following_url': 'https://api.github.com/users/efriis/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/efriis/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/efriis/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/efriis/subscriptions',
#     'organizations_url': 'https://api.github.com/users/efriis/orgs',
#     'repos_url': 'https://api.github.com/users/efriis/repos',
#     'events_url': 'https://api.github.com/users/efriis/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/efriis/received_events',
#     'type': 'User',
#     'site_admin': False}],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2024-08-24T01:28:08Z',
#   'updated_at': '2024-08-24T01:31:24Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/langchain-ai/langchain/pulls/25721',
#    'html_url': 'https://github.com/langchain-ai/langchain/pull/25721',
#    'diff_url': 'https://github.com/langchain-ai/langchain/pull/25721.diff',
#    'patch_url': 'https://github.com/langchain-ai/langchain/pull/25721.patch',
#    'merged_at': None},
#   'body': None,
#   'reactions': {'url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25721/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25721/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25718',
#   'repository_url': 'https://api.github.com/repos/langchain-ai/langchain',
#   'labels_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25718/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25718/comments',
#   'events_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25718/events',
#   'html_url': 'https://github.com/langchain-ai/langchain/issues/25718',
#   'id': 2484030894,
#   'node_id': 'I_kwDOIPDwls6UD02u',
#   'number': 25718,
#   'title': 'BlobLoader.yield_blobs returns Iterable, it should be Iterator like in BaseLoader',
#   'user': {'login': 'gabayben',
#    'id': 9704848,
#    'node_id': 'MDQ6VXNlcjk3MDQ4NDg=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/9704848?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/gabayben',
#    'html_url': 'https://github.com/gabayben',
#    'followers_url': 'https://api.github.com/users/gabayben/followers',
#    'following_url': 'https://api.github.com/users/gabayben/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/gabayben/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/gabayben/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/gabayben/subscriptions',
#    'organizations_url': 'https://api.github.com/users/gabayben/orgs',
#    'repos_url': 'https://api.github.com/users/gabayben/repos',
#    'events_url': 'https://api.github.com/users/gabayben/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/gabayben/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 5680700839,
#     'node_id': 'LA_kwDOIPDwls8AAAABUpidpw',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/%F0%9F%A4%96:bug',
#     'name': '🤖:bug',
#     'color': 'F9D0C4',
#     'default': False,
#     'description': 'Related to a bug, vulnerability, unexpected error with an existing feature'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': {'login': 'eyurtsev',
#    'id': 3205522,
#    'node_id': 'MDQ6VXNlcjMyMDU1MjI=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/3205522?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/eyurtsev',
#    'html_url': 'https://github.com/eyurtsev',
#    'followers_url': 'https://api.github.com/users/eyurtsev/followers',
#    'following_url': 'https://api.github.com/users/eyurtsev/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/eyurtsev/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/eyurtsev/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/eyurtsev/subscriptions',
#    'organizations_url': 'https://api.github.com/users/eyurtsev/orgs',
#    'repos_url': 'https://api.github.com/users/eyurtsev/repos',
#    'events_url': 'https://api.github.com/users/eyurtsev/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/eyurtsev/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'assignees': [{'login': 'eyurtsev',
#     'id': 3205522,
#     'node_id': 'MDQ6VXNlcjMyMDU1MjI=',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/3205522?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/eyurtsev',
#     'html_url': 'https://github.com/eyurtsev',
#     'followers_url': 'https://api.github.com/users/eyurtsev/followers',
#     'following_url': 'https://api.github.com/users/eyurtsev/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/eyurtsev/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/eyurtsev/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/eyurtsev/subscriptions',
#     'organizations_url': 'https://api.github.com/users/eyurtsev/orgs',
#     'repos_url': 'https://api.github.com/users/eyurtsev/repos',
#     'events_url': 'https://api.github.com/users/eyurtsev/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/eyurtsev/received_events',
#     'type': 'User',
#     'site_admin': False}],
#   'milestone': None,
#   'comments': 2,
#   'created_at': '2024-08-23T23:15:25Z',
#   'updated_at': '2024-08-25T03:36:16Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': '### Checked other resources\n\n- [X] I added a very descriptive title to this issue.\n- [X] I searched the LangChain documentation with the integrated search.\n- [X] I used the GitHub search to find a similar question and didn\'t find it.\n- [X] I am sure that this is a bug in LangChain rather than my code.\n- [X] The bug is not resolved by updating to the latest stable version of LangChain (or the specific integration package).\n\n### Example Code\n\nclass BlobLoader(ABC):\r\n    """Abstract interface for blob loaders implementation.\r\n\r\n    Implementer should be able to load raw content from a storage system according\r\n    to some criteria and return the raw content lazily as a stream of blobs.\r\n    """\r\n\r\n    @abstractmethod\r\n    def yield_blobs(\r\n        self,\r\n    ) -> Iterable[Blob]:\r\n        """A lazy loader for raw data represented by LangChain\'s Blob object.\r\n\r\n        Returns:\r\n            A generator over blobs\r\n        """\n\n### Error Message and Stack Trace (if applicable)\n\n_No response_\n\n### Description\n\nBlobLoader.yield_blobs returns Iterable, it should be Iterator like in BaseLoader\n\n### System Info\n\nBlobLoader.yield_blobs returns Iterable, it should be Iterator like in BaseLoader',
#   'reactions': {'url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25718/reactions',
#    'total_count': 1,
#    '+1': 1,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25718/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25711',
#   'repository_url': 'https://api.github.com/repos/langchain-ai/langchain',
#   'labels_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25711/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25711/comments',
#   'events_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25711/events',
#   'html_url': 'https://github.com/langchain-ai/langchain/pull/25711',
#   'id': 2483652426,
#   'node_id': 'PR_kwDOIPDwls55Rj_N',
#   'number': 25711,
#   'title': 'docs: `integrations` reference updates 13',
#   'user': {'login': 'leo-gan',
#    'id': 2256422,
#    'node_id': 'MDQ6VXNlcjIyNTY0MjI=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/2256422?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/leo-gan',
#    'html_url': 'https://github.com/leo-gan',
#    'followers_url': 'https://api.github.com/users/leo-gan/followers',
#    'following_url': 'https://api.github.com/users/leo-gan/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/leo-gan/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/leo-gan/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/leo-gan/subscriptions',
#    'organizations_url': 'https://api.github.com/users/leo-gan/orgs',
#    'repos_url': 'https://api.github.com/users/leo-gan/repos',
#    'events_url': 'https://api.github.com/users/leo-gan/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/leo-gan/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 5541432778,
#     'node_id': 'LA_kwDOIPDwls8AAAABSkuNyg',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/%E2%B1%AD:%20vector%20store',
#     'name': 'Ɑ: vector store',
#     'color': 'D4C5F9',
#     'default': False,
#     'description': 'Related to vector store module'},
#    {'id': 5680700918,
#     'node_id': 'LA_kwDOIPDwls8AAAABUpid9g',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/%F0%9F%A4%96:docs',
#     'name': '🤖:docs',
#     'color': 'C5DEF5',
#     'default': False,
#     'description': 'Changes to documentation and examples, like .md, .rst, .ipynb files. Changes to the docs/ folder'},
#    {'id': 6232714126,
#     'node_id': 'LA_kwDOIPDwls8AAAABc3-rjg',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/size:L',
#     'name': 'size:L',
#     'color': 'F9D0C4',
#     'default': False,
#     'description': 'This PR changes 100-499 lines, ignoring generated files.'},
#    {'id': 6471842532,
#     'node_id': 'LA_kwDOIPDwls8AAAABgcB65A',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/%F0%9F%94%8C:%20qdrant',
#     'name': '🔌: qdrant',
#     'color': 'BFD4F2',
#     'default': False,
#     'description': 'Primarily related to Qdrant vector store integration'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2024-08-23T18:23:35Z',
#   'updated_at': '2024-08-23T23:47:58Z',
#   'closed_at': None,
#   'author_association': 'COLLABORATOR',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/langchain-ai/langchain/pulls/25711',
#    'html_url': 'https://github.com/langchain-ai/langchain/pull/25711',
#    'diff_url': 'https://github.com/langchain-ai/langchain/pull/25711.diff',
#    'patch_url': 'https://github.com/langchain-ai/langchain/pull/25711.patch',
#    'merged_at': None},
#   'body': 'Added missed provider pages and links. Fixed inconsistent formatting.\r\nAdded arxiv references to docstirngs.',
#   'reactions': {'url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25711/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25711/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25703',
#   'repository_url': 'https://api.github.com/repos/langchain-ai/langchain',
#   'labels_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25703/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25703/comments',
#   'events_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25703/events',
#   'html_url': 'https://github.com/langchain-ai/langchain/issues/25703',
#   'id': 2483396136,
#   'node_id': 'I_kwDOIPDwls6UBZ4o',
#   'number': 25703,
#   'title': 'prompty: Superfluous f-string templating causes prompt templaing to fail',
#   'user': {'login': 'matthieucx',
#    'id': 11246353,
#    'node_id': 'MDQ6VXNlcjExMjQ2MzUz',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/11246353?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/matthieucx',
#    'html_url': 'https://github.com/matthieucx',
#    'followers_url': 'https://api.github.com/users/matthieucx/followers',
#    'following_url': 'https://api.github.com/users/matthieucx/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/matthieucx/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/matthieucx/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/matthieucx/subscriptions',
#    'organizations_url': 'https://api.github.com/users/matthieucx/orgs',
#    'repos_url': 'https://api.github.com/users/matthieucx/repos',
#    'events_url': 'https://api.github.com/users/matthieucx/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/matthieucx/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 5680700839,
#     'node_id': 'LA_kwDOIPDwls8AAAABUpidpw',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/%F0%9F%A4%96:bug',
#     'name': '🤖:bug',
#     'color': 'F9D0C4',
#     'default': False,
#     'description': 'Related to a bug, vulnerability, unexpected error with an existing feature'},
#    {'id': 6713033886,
#     'node_id': 'LA_kwDOIPDwls8AAAABkCDEng',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/%E2%B1%AD:%20%20core',
#     'name': 'Ɑ:  core',
#     'color': 'D4C5F9',
#     'default': False,
#     'description': 'Related to langchain-core'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2024-08-23T15:34:14Z',
#   'updated_at': '2024-08-23T15:37:01Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
# ...
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/langchain-ai/langchain/pulls/25652',
#    'html_url': 'https://github.com/langchain-ai/langchain/pull/25652',
#    'diff_url': 'https://github.com/langchain-ai/langchain/pull/25652.diff',
#    'patch_url': 'https://github.com/langchain-ai/langchain/pull/25652.patch',
#    'merged_at': None},
#   'body': 'Thank you for contributing to LangChain!\r\n\r\n- [x] **PR title**: "package: description"\r\n  - Where "package" is whichever of langchain, community, core, experimental, etc. is being modified. Use "docs: ..." for purely docs changes, "templates: ..." for template changes, "infra: ..." for CI changes.\r\n  - Example: "community: add foobar LLM"\r\n\r\n\r\nSupport passing extra params when executing UC functions:\r\nThe params should be a dictionary with key EXECUTE_FUNCTION_ARG_NAME, the assumption is that the function itself doesn\'t use such variable name (starting and ending with double underscores), and if it does we raise Exception.\r\nIf invalid params passing to the execute_statement, we raise Exception as well.\r\n\r\n\r\n- [x] **Add tests and docs**: If you\'re adding a new integration, please include\r\n  1. a test for the integration, preferably unit tests that do not rely on network access,\r\n  2. an example notebook showing its use. It lives in `docs/docs/integrations` directory.\r\n\r\n\r\n- [x] **Lint and test**: Run `make format`, `make lint` and `make test` from the root of the package(s) you\'ve modified. See contribution guidelines for more: https://python.langchain.com/docs/contributing/\r\n\r\nAdditional guidelines:\r\n- Make sure optional dependencies are imported within a function.\r\n- Please do not add dependencies to pyproject.toml files (even optional ones) unless they are required for unit tests.\r\n- Most PRs should not touch more than one package.\r\n- Changes should be backwards compatible.\r\n- If you are adding something to community, do not re-import it in langchain.\r\n\r\nIf no one reviews your PR within a few days, please @-mention one of baskaryan, efriis, eyurtsev, ccurme, vbarda, hwchase17.\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25652/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25652/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25651',
#   'repository_url': 'https://api.github.com/repos/langchain-ai/langchain',
#   'labels_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25651/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25651/comments',
#   'events_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25651/events',
#   'html_url': 'https://github.com/langchain-ai/langchain/issues/25651',
#   'id': 2479699061,
#   'node_id': 'I_kwDOIPDwls6TzTR1',
#   'number': 25651,
#   'title': 'chroma impl issue',
#   'user': {'login': 'tkb1902',
#    'id': 138828337,
#    'node_id': 'U_kgDOCEZaMQ',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/138828337?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/tkb1902',
#    'html_url': 'https://github.com/tkb1902',
#    'followers_url': 'https://api.github.com/users/tkb1902/followers',
#    'following_url': 'https://api.github.com/users/tkb1902/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/tkb1902/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/tkb1902/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/tkb1902/subscriptions',
#    'organizations_url': 'https://api.github.com/users/tkb1902/orgs',
#    'repos_url': 'https://api.github.com/users/tkb1902/repos',
#    'events_url': 'https://api.github.com/users/tkb1902/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/tkb1902/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 5680700839,
#     'node_id': 'LA_kwDOIPDwls8AAAABUpidpw',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/%F0%9F%A4%96:bug',
#     'name': '🤖:bug',
#     'color': 'F9D0C4',
#     'default': False,
#     'description': 'Related to a bug, vulnerability, unexpected error with an existing feature'},
#    {'id': 5924999838,
#     'node_id': 'LA_kwDOIPDwls8AAAABYShSng',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/%F0%9F%94%8C:%20chroma',
#     'name': '🔌: chroma',
#     'color': 'BFD4F2',
#     'default': False,
#     'description': 'Primarily related to ChromaDB integrations'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2024-08-22T03:44:55Z',
#   'updated_at': '2024-08-22T03:47:28Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': '### Checked other resources\n\n- [X] I added a very descriptive title to this issue.\n- [X] I searched the LangChain documentation with the integrated search.\n- [X] I used the GitHub search to find a similar question and didn\'t find it.\n- [X] I am sure that this is a bug in LangChain rather than my code.\n- [X] The bug is not resolved by updating to the latest stable version of LangChain (or the specific integration package).\n\n### Example Code\n\n\'\'\'python\r\nimport HuggingFaceEmbeddings\r\nfrom langchain_community.document_loaders import DirectoryLoader, PDFMinerLoader, PyPDFLoader\r\nfrom langchain_text_splitters import RecursiveCharacterTextSplitter\r\nfrom langchain_community.vectorstores import Chroma\r\nfrom constants import CHROMA_SETTINGS\r\n\r\npersist_directory = "db"\r\n\r\ndef main():\r\n    for root, dirs, files in os.walk("docs"):\r\n        for file in files:\r\n            if file.endswith(".pdf"):\r\n                print(file)\r\n                loader = PyPDFLoader(os.path.join(root, file))\r\n                documents = loader.load()  # Moved inside the if statement to ensure documents are loaded only for PDFs\r\n                print("splitting into chunks")\r\n                text_splitter = RecursiveCharacterTextSplitter(chunk_size=500, chunk_overlap=100)\r\n                texts = text_splitter.split_documents(documents)\r\n                # create embeddings here\r\n                print("Loading sentence transformers model")\r\n                embeddings =HuggingFaceEmbeddings(model_name="all-MiniLM-L6-v2")\r\n                # create vector store here\r\n                print(f"Creating embeddings. May take some minutes...")\r\n                db = Chroma.from_documents(texts, embeddings, persist_directory=persist_directory, client_settings=CHROMA_SETTINGS)\r\n                db.persist()\r\n                db = None\r\n\r\n    print(f"Ingestion complete! You can now run privateGPT.py to query your documents")\r\n\r\nif __name__ == "__main__":\r\n    main()\r\n\'\'\'\n\n### Error Message and Stack Trace (if applicable)\n\n(env) PS C:\\Users\\USER\\Documents\\models\\chatToPdf\\Chat-with-PDF-Chatbot> & c:/Users/USER/Documents/models/chatToPdf/Chat-with-PDF-Chatbot/env/Scripts/python.exe c:/Users/USER/Documents/models/chatToPdf/Chat-with-PDF-Chatbot/ingest.py\r\nduckdb+parquet\r\ndb\r\nTrue\r\nApplied Natural Language Processing with Python_ Implementing Machine Learning and Deep Learning Algorithms for Natural Language Processing ( PDFDrive ).pdf\r\nsplitting into chunks\r\nLoading sentence transformers model\r\nC:\\Users\\USER\\Documents\\models\\chatToPdf\\Chat-with-PDF-Chatbot\\env\\Lib\\site-packages\\transformers\\tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to \r\n`True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884\r\n  warnings.warn(\r\nCreating embeddings. May take some minutes...\r\nTraceback (most recent call last):\r\n  File "c:\\Users\\USER\\Documents\\models\\chatToPdf\\Chat-with-PDF-Chatbot\\ingest.py", line 32, in <module>\r\n    main()\r\n  File "c:\\Users\\USER\\Documents\\models\\chatToPdf\\Chat-with-PDF-Chatbot\\ingest.py", line 25, in main\r\n    db = Chroma.from_documents(texts, embeddings, persist_directory=persist_directory, client_settings=CHROMA_SETTINGS)\r\n         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\r\n  File "C:\\Users\\USER\\Documents\\models\\chatToPdf\\Chat-with-PDF-Chatbot\\env\\Lib\\site-packages\\langchain_community\\vectorstores\\chroma.py", line 878, in from_documents\r\n    return cls.from_texts(\r\ntings)\r\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^env\\Lib\\site-packages\\langchain_community\\vectorstores\\chroma.py", line 8 ...
#   'reactions': {'url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25651/reactions',
#    'total_count': 1,
#    '+1': 1,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25651/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25650',
#   'repository_url': 'https://api.github.com/repos/langchain-ai/langchain',
#   'labels_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25650/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25650/comments',
#   'events_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25650/events',
#   'html_url': 'https://github.com/langchain-ai/langchain/pull/25650',
#   'id': 2479686140,
#   'node_id': 'PR_kwDOIPDwls55EaTn',
#   'number': 25650,
#   'title': 'docs: sorted Templates menu',
#   'user': {'login': 'leo-gan',
#    'id': 2256422,
#    'node_id': 'MDQ6VXNlcjIyNTY0MjI=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/2256422?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/leo-gan',
#    'html_url': 'https://github.com/leo-gan',
#    'followers_url': 'https://api.github.com/users/leo-gan/followers',
#    'following_url': 'https://api.github.com/users/leo-gan/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/leo-gan/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/leo-gan/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/leo-gan/subscriptions',
#    'organizations_url': 'https://api.github.com/users/leo-gan/orgs',
#    'repos_url': 'https://api.github.com/users/leo-gan/repos',
#    'events_url': 'https://api.github.com/users/leo-gan/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/leo-gan/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2024-08-22T03:29:26Z',
#   'updated_at': '2024-08-22T03:35:07Z',
#   'closed_at': None,
#   'author_association': 'COLLABORATOR',
#   'active_lock_reason': None,
#   'draft': True,
#   'pull_request': {'url': 'https://api.github.com/repos/langchain-ai/langchain/pulls/25650',
#    'html_url': 'https://github.com/langchain-ai/langchain/pull/25650',
#    'diff_url': 'https://github.com/langchain-ai/langchain/pull/25650.diff',
#    'patch_url': 'https://github.com/langchain-ai/langchain/pull/25650.patch',
#    'merged_at': None},
#   'body': 'The Templates menu is sorted by the file names.\r\nI want to sort in by the Titles (where Title is a line, started with "# " (H1)).',
#   'reactions': {'url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25650/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25650/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25645',
#   'repository_url': 'https://api.github.com/repos/langchain-ai/langchain',
#   'labels_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25645/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25645/comments',
#   'events_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25645/events',
#   'html_url': 'https://github.com/langchain-ai/langchain/pull/25645',
#   'id': 2479421460,
#   'node_id': 'PR_kwDOIPDwls55Dpqj',
#   'number': 25645,
#   'title': 'core[patch]: support additional kwargs on StructuredPrompt',
#   'user': {'login': 'baskaryan',
#    'id': 22008038,
#    'node_id': 'MDQ6VXNlcjIyMDA4MDM4',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/22008038?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/baskaryan',
#    'html_url': 'https://github.com/baskaryan',
#    'followers_url': 'https://api.github.com/users/baskaryan/followers',
#    'following_url': 'https://api.github.com/users/baskaryan/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/baskaryan/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/baskaryan/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/baskaryan/subscriptions',
#    'organizations_url': 'https://api.github.com/users/baskaryan/orgs',
#    'repos_url': 'https://api.github.com/users/baskaryan/repos',
#    'events_url': 'https://api.github.com/users/baskaryan/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/baskaryan/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 5680700873,
#     'node_id': 'LA_kwDOIPDwls8AAAABUpidyQ',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/%F0%9F%A4%96:improvement',
#     'name': '🤖:improvement',
#     'color': 'C5DEF5',
#     'default': False,
#     'description': 'Medium size change to existing code to handle new use-cases'},
#    {'id': 6232714126,
#     'node_id': 'LA_kwDOIPDwls8AAAABc3-rjg',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/size:L',
#     'name': 'size:L',
#     'color': 'F9D0C4',
#     'default': False,
#     'description': 'This PR changes 100-499 lines, ignoring generated files.'},
#    {'id': 6713033886,
#     'node_id': 'LA_kwDOIPDwls8AAAABkCDEng',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/%E2%B1%AD:%20%20core',
#     'name': 'Ɑ:  core',
#     'color': 'D4C5F9',
#     'default': False,
#     'description': 'Related to langchain-core'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2024-08-21T23:32:29Z',
#   'updated_at': '2024-08-22T20:11:04Z',
#   'closed_at': None,
#   'author_association': 'COLLABORATOR',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/langchain-ai/langchain/pulls/25645',
#    'html_url': 'https://github.com/langchain-ai/langchain/pull/25645',
#    'diff_url': 'https://github.com/langchain-ai/langchain/pull/25645.diff',
#    'patch_url': 'https://github.com/langchain-ai/langchain/pull/25645.patch',
#    'merged_at': None},
#   'body': None,
#   'reactions': {'url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25645/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25645/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None}]

# %% [markdown]
# ### List Pull Requests API
#
# API完整文档说明见：https://docs.github.com/en/rest/pulls/pulls?apiVersion=2022-11-28#list-pull-requests
#
# **请求样例**：`GET /repos/{owner}/{repo}/pulls`;

# %%
pull_requests = github_client.fetch_pull_requests(repo)

# %%
pull_requests
# Out:
# [{'url': 'https://api.github.com/repos/langchain-ai/langchain/pulls/25729',
#   'id': 2035737702,
#   'node_id': 'PR_kwDOIPDwls55VuRm',
#   'html_url': 'https://github.com/langchain-ai/langchain/pull/25729',
#   'diff_url': 'https://github.com/langchain-ai/langchain/pull/25729.diff',
#   'patch_url': 'https://github.com/langchain-ai/langchain/pull/25729.patch',
#   'issue_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25729',
#   'number': 25729,
#   'state': 'open',
#   'locked': False,
#   'title': 'core[patch]: Release 0.2.35',
#   'user': {'login': 'baskaryan',
#    'id': 22008038,
#    'node_id': 'MDQ6VXNlcjIyMDA4MDM4',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/22008038?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/baskaryan',
#    'html_url': 'https://github.com/baskaryan',
#    'followers_url': 'https://api.github.com/users/baskaryan/followers',
#    'following_url': 'https://api.github.com/users/baskaryan/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/baskaryan/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/baskaryan/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/baskaryan/subscriptions',
#    'organizations_url': 'https://api.github.com/users/baskaryan/orgs',
#    'repos_url': 'https://api.github.com/users/baskaryan/repos',
#    'events_url': 'https://api.github.com/users/baskaryan/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/baskaryan/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'body': None,
#   'created_at': '2024-08-24T23:07:38Z',
#   'updated_at': '2024-08-24T23:08:07Z',
#   'closed_at': None,
#   'merged_at': None,
#   'merge_commit_sha': '9f75d8ed2f08d4d49e432cc4fbf0713bcc54fd26',
#   'assignee': None,
#   'assignees': [],
#   'requested_reviewers': [],
#   'requested_teams': [],
#   'labels': [{'id': 6232714104,
#     'node_id': 'LA_kwDOIPDwls8AAAABc3-reA',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/size:XS',
#     'name': 'size:XS',
#     'color': 'C2E0C6',
#     'default': False,
#     'description': 'This PR changes 0-9 lines, ignoring generated files.'},
#    {'id': 6467902041,
#     'node_id': 'LA_kwDOIPDwls8AAAABgYRaWQ',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/%F0%9F%A4%96:release',
#     'name': '🤖:release',
#     'color': 'C5DEF5',
#     'default': False,
#     'description': 'Bumping package version for release'}],
#   'milestone': None,
#   'draft': False,
#   'commits_url': 'https://api.github.com/repos/langchain-ai/langchain/pulls/25729/commits',
#   'review_comments_url': 'https://api.github.com/repos/langchain-ai/langchain/pulls/25729/comments',
#   'review_comment_url': 'https://api.github.com/repos/langchain-ai/langchain/pulls/comments{/number}',
#   'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25729/comments',
#   'statuses_url': 'https://api.github.com/repos/langchain-ai/langchain/statuses/9db7ced95cabf5f849224e3ce350326a81047348',
#   'head': {'label': 'langchain-ai:bagatur/core_0_2_35',
#    'ref': 'bagatur/core_0_2_35',
#    'sha': '9db7ced95cabf5f849224e3ce350326a81047348',
#    'user': {'login': 'langchain-ai',
#     'id': 126733545,
#     'node_id': 'O_kgDOB43M6Q',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/126733545?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/langchain-ai',
#     'html_url': 'https://github.com/langchain-ai',
#     'followers_url': 'https://api.github.com/users/langchain-ai/followers',
#     'following_url': 'https://api.github.com/users/langchain-ai/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/langchain-ai/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/langchain-ai/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/langchain-ai/subscriptions',
#     'organizations_url': 'https://api.github.com/users/langchain-ai/orgs',
#     'repos_url': 'https://api.github.com/users/langchain-ai/repos',
#     'events_url': 'https://api.github.com/users/langchain-ai/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/langchain-ai/received_events',
#     'type': 'Organization',
#     'site_admin': False},
#    'repo': {'id': 552661142,
#     'node_id': 'R_kgDOIPDwlg',
#     'name': 'langchain',
#     'full_name': 'langchain-ai/langchain',
#     'private': False,
#     'owner': {'login': 'langchain-ai',
#      'id': 126733545,
#      'node_id': 'O_kgDOB43M6Q',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/126733545?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/langchain-ai',
#      'html_url': 'https://github.com/langchain-ai',
#      'followers_url': 'https://api.github.com/users/langchain-ai/followers',
#      'following_url': 'https://api.github.com/users/langchain-ai/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/langchain-ai/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/langchain-ai/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/langchain-ai/subscriptions',
#      'organizations_url': 'https://api.github.com/users/langchain-ai/orgs',
#      'repos_url': 'https://api.github.com/users/langchain-ai/repos',
#      'events_url': 'https://api.github.com/users/langchain-ai/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/langchain-ai/received_events',
#      'type': 'Organization',
#      'site_admin': False},
#     'html_url': 'https://github.com/langchain-ai/langchain',
#     'description': '🦜🔗 Build context-aware reasoning applications',
#     'fork': False,
#     'url': 'https://api.github.com/repos/langchain-ai/langchain',
#     'forks_url': 'https://api.github.com/repos/langchain-ai/langchain/forks',
#     'keys_url': 'https://api.github.com/repos/langchain-ai/langchain/keys{/key_id}',
#     'collaborators_url': 'https://api.github.com/repos/langchain-ai/langchain/collaborators{/collaborator}',
#     'teams_url': 'https://api.github.com/repos/langchain-ai/langchain/teams',
#     'hooks_url': 'https://api.github.com/repos/langchain-ai/langchain/hooks',
#     'issue_events_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/events{/number}',
#     'events_url': 'https://api.github.com/repos/langchain-ai/langchain/events',
#     'assignees_url': 'https://api.github.com/repos/langchain-ai/langchain/assignees{/user}',
#     'branches_url': 'https://api.github.com/repos/langchain-ai/langchain/branches{/branch}',
#     'tags_url': 'https://api.github.com/repos/langchain-ai/langchain/tags',
#     'blobs_url': 'https://api.github.com/repos/langchain-ai/langchain/git/blobs{/sha}',
#     'git_tags_url': 'https://api.github.com/repos/langchain-ai/langchain/git/tags{/sha}',
#     'git_refs_url': 'https://api.github.com/repos/langchain-ai/langchain/git/refs{/sha}',
#     'trees_url': 'https://api.github.com/repos/langchain-ai/langchain/git/trees{/sha}',
#     'statuses_url': 'https://api.github.com/repos/langchain-ai/langchain/statuses/{sha}',
#     'languages_url': 'https://api.github.com/repos/langchain-ai/langchain/languages',
#     'stargazers_url': 'https://api.github.com/repos/langchain-ai/langchain/stargazers',
#     'contributors_url': 'https://api.github.com/repos/langchain-ai/langchain/contributors',
#     'subscribers_url': 'https://api.github.com/repos/langchain-ai/langchain/subscribers',
#     'subscription_url': 'https://api.github.com/repos/langchain-ai/langchain/subscription',
#     'commits_url': 'https://api.github.com/repos/langchain-ai/langchain/commits{/sha}',
#     'git_commits_url': 'https://api.github.com/repos/langchain-ai/langchain/git/commits{/sha}',
#     'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/comments{/number}',
#     'issue_comment_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/comments{/number}',
#     'contents_url': 'https://api.github.com/repos/langchain-ai/langchain/contents/{+path}',
#     'compare_url': 'https://api.github.com/repos/langchain-ai/langchain/compare/{base}...{head}',
#     'merges_url': 'https://api.github.com/repos/langchain-ai/langchain/merges',
#     'archive_url': 'https://api.github.com/repos/langchain-ai/langchain/{archive_format}{/ref}',
#     'downloads_url': 'https://api.github.com/repos/langchain-ai/langchain/downloads',
#     'issues_url': 'https://api.github.com/repos/langchain-ai/langchain/issues{/number}',
#     'pulls_url': 'https://api.github.com/repos/langchain-ai/langchain/pulls{/number}',
#     'milestones_url': 'https://api.github.com/repos/langchain-ai/langchain/milestones{/number}',
#     'notifications_url': 'https://api.github.com/repos/langchain-ai/langchain/notifications{?since,all,participating}',
#     'labels_url': 'https://api.github.com/repos/langchain-ai/langchain/labels{/name}',
#     'releases_url': 'https://api.github.com/repos/langchain-ai/langchain/releases{/id}',
#     'deployments_url': 'https://api.github.com/repos/langchain-ai/langchain/deployments',
#     'created_at': '2022-10-17T02:58:36Z',
#     'updated_at': '2024-08-25T02:02:41Z',
#     'pushed_at': '2024-08-24T23:07:26Z',
#     'git_url': 'git://github.com/langchain-ai/langchain.git',
#     'ssh_url': 'git@github.com:langchain-ai/langchain.git',
#     'clone_url': 'https://github.com/langchain-ai/langchain.git',
#     'svn_url': 'https://github.com/langchain-ai/langchain',
#     'homepage': 'https://python.langchain.com',
#     'size': 290361,
#     'stargazers_count': 91185,
#     'watchers_count': 91185,
#     'language': 'Jupyter Notebook',
#     'has_issues': True,
#     'has_projects': True,
#     'has_downloads': True,
#     'has_wiki': True,
#     'has_pages': False,
#     'has_discussions': True,
#     'forks_count': 14493,
#     'mirror_url': None,
#     'archived': False,
#     'disabled': False,
#     'open_issues_count': 898,
#     'license': {'key': 'mit',
#      'name': 'MIT License',
#      'spdx_id': 'MIT',
#      'url': 'https://api.github.com/licenses/mit',
#      'node_id': 'MDc6TGljZW5zZTEz'},
#     'allow_forking': True,
#     'is_template': False,
#     'web_commit_signoff_required': False,
#     'topics': [],
#     'visibility': 'public',
#     'forks': 14493,
#     'open_issues': 898,
#     'watchers': 91185,
#     'default_branch': 'master'}},
#   'base': {'label': 'langchain-ai:master',
#    'ref': 'master',
#    'sha': '038c287b3a17d10da1000c7b5827ca7dc6d560a5',
#    'user': {'login': 'langchain-ai',
#     'id': 126733545,
#     'node_id': 'O_kgDOB43M6Q',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/126733545?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/langchain-ai',
#     'html_url': 'https://github.com/langchain-ai',
#     'followers_url': 'https://api.github.com/users/langchain-ai/followers',
#     'following_url': 'https://api.github.com/users/langchain-ai/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/langchain-ai/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/langchain-ai/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/langchain-ai/subscriptions',
#     'organizations_url': 'https://api.github.com/users/langchain-ai/orgs',
#     'repos_url': 'https://api.github.com/users/langchain-ai/repos',
#     'events_url': 'https://api.github.com/users/langchain-ai/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/langchain-ai/received_events',
#     'type': 'Organization',
#     'site_admin': False},
#    'repo': {'id': 552661142,
#     'node_id': 'R_kgDOIPDwlg',
#     'name': 'langchain',
#     'full_name': 'langchain-ai/langchain',
#     'private': False,
#     'owner': {'login': 'langchain-ai',
#      'id': 126733545,
#      'node_id': 'O_kgDOB43M6Q',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/126733545?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/langchain-ai',
#      'html_url': 'https://github.com/langchain-ai',
#      'followers_url': 'https://api.github.com/users/langchain-ai/followers',
#      'following_url': 'https://api.github.com/users/langchain-ai/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/langchain-ai/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/langchain-ai/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/langchain-ai/subscriptions',
#      'organizations_url': 'https://api.github.com/users/langchain-ai/orgs',
#      'repos_url': 'https://api.github.com/users/langchain-ai/repos',
#      'events_url': 'https://api.github.com/users/langchain-ai/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/langchain-ai/received_events',
#      'type': 'Organization',
#      'site_admin': False},
#     'html_url': 'https://github.com/langchain-ai/langchain',
#     'description': '🦜🔗 Build context-aware reasoning applications',
#     'fork': False,
#     'url': 'https://api.github.com/repos/langchain-ai/langchain',
#     'forks_url': 'https://api.github.com/repos/langchain-ai/langchain/forks',
#     'keys_url': 'https://api.github.com/repos/langchain-ai/langchain/keys{/key_id}',
#     'collaborators_url': 'https://api.github.com/repos/langchain-ai/langchain/collaborators{/collaborator}',
#     'teams_url': 'https://api.github.com/repos/langchain-ai/langchain/teams',
#     'hooks_url': 'https://api.github.com/repos/langchain-ai/langchain/hooks',
#     'issue_events_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/events{/number}',
#     'events_url': 'https://api.github.com/repos/langchain-ai/langchain/events',
#     'assignees_url': 'https://api.github.com/repos/langchain-ai/langchain/assignees{/user}',
#     'branches_url': 'https://api.github.com/repos/langchain-ai/langchain/branches{/branch}',
#     'tags_url': 'https://api.github.com/repos/langchain-ai/langchain/tags',
#     'blobs_url': 'https://api.github.com/repos/langchain-ai/langchain/git/blobs{/sha}',
#     'git_tags_url': 'https://api.github.com/repos/langchain-ai/langchain/git/tags{/sha}',
#     'git_refs_url': 'https://api.github.com/repos/langchain-ai/langchain/git/refs{/sha}',
#     'trees_url': 'https://api.github.com/repos/langchain-ai/langchain/git/trees{/sha}',
#     'statuses_url': 'https://api.github.com/repos/langchain-ai/langchain/statuses/{sha}',
#     'languages_url': 'https://api.github.com/repos/langchain-ai/langchain/languages',
#     'stargazers_url': 'https://api.github.com/repos/langchain-ai/langchain/stargazers',
#     'contributors_url': 'https://api.github.com/repos/langchain-ai/langchain/contributors',
#     'subscribers_url': 'https://api.github.com/repos/langchain-ai/langchain/subscribers',
#     'subscription_url': 'https://api.github.com/repos/langchain-ai/langchain/subscription',
#     'commits_url': 'https://api.github.com/repos/langchain-ai/langchain/commits{/sha}',
#     'git_commits_url': 'https://api.github.com/repos/langchain-ai/langchain/git/commits{/sha}',
#     'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/comments{/number}',
#     'issue_comment_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/comments{/number}',
#     'contents_url': 'https://api.github.com/repos/langchain-ai/langchain/contents/{+path}',
#     'compare_url': 'https://api.github.com/repos/langchain-ai/langchain/compare/{base}...{head}',
#     'merges_url': 'https://api.github.com/repos/langchain-ai/langchain/merges',
#     'archive_url': 'https://api.github.com/repos/langchain-ai/langchain/{archive_format}{/ref}',
#     'downloads_url': 'https://api.github.com/repos/langchain-ai/langchain/downloads',
#     'issues_url': 'https://api.github.com/repos/langchain-ai/langchain/issues{/number}',
#     'pulls_url': 'https://api.github.com/repos/langchain-ai/langchain/pulls{/number}',
#     'milestones_url': 'https://api.github.com/repos/langchain-ai/langchain/milestones{/number}',
#     'notifications_url': 'https://api.github.com/repos/langchain-ai/langchain/notifications{?since,all,participating}',
#     'labels_url': 'https://api.github.com/repos/langchain-ai/langchain/labels{/name}',
#     'releases_url': 'https://api.github.com/repos/langchain-ai/langchain/releases{/id}',
#     'deployments_url': 'https://api.github.com/repos/langchain-ai/langchain/deployments',
#     'created_at': '2022-10-17T02:58:36Z',
#     'updated_at': '2024-08-25T02:02:41Z',
#     'pushed_at': '2024-08-24T23:07:26Z',
#     'git_url': 'git://github.com/langchain-ai/langchain.git',
#     'ssh_url': 'git@github.com:langchain-ai/langchain.git',
#     'clone_url': 'https://github.com/langchain-ai/langchain.git',
#     'svn_url': 'https://github.com/langchain-ai/langchain',
#     'homepage': 'https://python.langchain.com',
#     'size': 290361,
#     'stargazers_count': 91185,
#     'watchers_count': 91185,
#     'language': 'Jupyter Notebook',
#     'has_issues': True,
#     'has_projects': True,
#     'has_downloads': True,
#     'has_wiki': True,
#     'has_pages': False,
#     'has_discussions': True,
#     'forks_count': 14493,
#     'mirror_url': None,
#     'archived': False,
#     'disabled': False,
#     'open_issues_count': 898,
#     'license': {'key': 'mit',
#      'name': 'MIT License',
#      'spdx_id': 'MIT',
#      'url': 'https://api.github.com/licenses/mit',
#      'node_id': 'MDc6TGljZW5zZTEz'},
#     'allow_forking': True,
#     'is_template': False,
#     'web_commit_signoff_required': False,
#     'topics': [],
#     'visibility': 'public',
#     'forks': 14493,
#     'open_issues': 898,
#     'watchers': 91185,
#     'default_branch': 'master'}},
#   '_links': {'self': {'href': 'https://api.github.com/repos/langchain-ai/langchain/pulls/25729'},
#    'html': {'href': 'https://github.com/langchain-ai/langchain/pull/25729'},
#    'issue': {'href': 'https://api.github.com/repos/langchain-ai/langchain/issues/25729'},
#    'comments': {'href': 'https://api.github.com/repos/langchain-ai/langchain/issues/25729/comments'},
#    'review_comments': {'href': 'https://api.github.com/repos/langchain-ai/langchain/pulls/25729/comments'},
#    'review_comment': {'href': 'https://api.github.com/repos/langchain-ai/langchain/pulls/comments{/number}'},
#    'commits': {'href': 'https://api.github.com/repos/langchain-ai/langchain/pulls/25729/commits'},
#    'statuses': {'href': 'https://api.github.com/repos/langchain-ai/langchain/statuses/9db7ced95cabf5f849224e3ce350326a81047348'}},
#   'author_association': 'COLLABORATOR',
#   'auto_merge': None,
#   'active_lock_reason': None},
#  {'url': 'https://api.github.com/repos/langchain-ai/langchain/pulls/25728',
#   'id': 2035736964,
#   'node_id': 'PR_kwDOIPDwls55VuGE',
#   'html_url': 'https://github.com/langchain-ai/langchain/pull/25728',
#   'diff_url': 'https://github.com/langchain-ai/langchain/pull/25728.diff',
#   'patch_url': 'https://github.com/langchain-ai/langchain/pull/25728.patch',
#   'issue_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25728',
#   'number': 25728,
#   'state': 'open',
#   'locked': False,
#   'title': 'community: Minor Improvement of extract hyperlinks tool output',
#   'user': {'login': 'zysoong',
#    'id': 75294755,
#    'node_id': 'MDQ6VXNlcjc1Mjk0NzU1',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/75294755?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/zysoong',
#    'html_url': 'https://github.com/zysoong',
#    'followers_url': 'https://api.github.com/users/zysoong/followers',
#    'following_url': 'https://api.github.com/users/zysoong/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/zysoong/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/zysoong/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/zysoong/subscriptions',
#    'organizations_url': 'https://api.github.com/users/zysoong/orgs',
#    'repos_url': 'https://api.github.com/users/zysoong/repos',
#    'events_url': 'https://api.github.com/users/zysoong/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/zysoong/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'body': "**Description:** Make the hyperlink only appear once in the extract_hyperlinks tool output. (for some websites output contains meaningless '#' hyperlinks multiple times which will extend the tokens of context window without any advantage)\r\n**Issue:** None\r\n**Dependencies:** None\r\n",
#   'created_at': '2024-08-24T23:04:44Z',
#   'updated_at': '2024-08-24T23:20:38Z',
#   'closed_at': None,
#   'merged_at': None,
#   'merge_commit_sha': '77dd4f017d985db3450e2c969ae081991b363184',
#   'assignee': None,
#   'assignees': [],
#   'requested_reviewers': [],
#   'requested_teams': [],
#   'labels': [{'id': 5680700883,
#     'node_id': 'LA_kwDOIPDwls8AAAABUpid0w',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/%F0%9F%A4%96:nit',
#     'name': '🤖:nit',
#     'color': 'C5DEF5',
#     'default': False,
#     'description': 'Small modifications/deletions, fixes, deps or improvements to existing code or docs'},
#    {'id': 6232714104,
#     'node_id': 'LA_kwDOIPDwls8AAAABc3-reA',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/size:XS',
#     'name': 'size:XS',
#     'color': 'C2E0C6',
#     'default': False,
#     'description': 'This PR changes 0-9 lines, ignoring generated files.'},
#    {'id': 7097373342,
#     'node_id': 'LA_kwDOIPDwls8AAAABpwlSng',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/community',
#     'name': 'community',
#     'color': '579082',
#     'default': False,
#     'description': 'Related to langchain-community'}],
#   'milestone': None,
#   'draft': False,
#   'commits_url': 'https://api.github.com/repos/langchain-ai/langchain/pulls/25728/commits',
#   'review_comments_url': 'https://api.github.com/repos/langchain-ai/langchain/pulls/25728/comments',
#   'review_comment_url': 'https://api.github.com/repos/langchain-ai/langchain/pulls/comments{/number}',
#   'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25728/comments',
#   'statuses_url': 'https://api.github.com/repos/langchain-ai/langchain/statuses/705be50e14d7b9dd8d986b0aef07a7833a8dd4c7',
#   'head': {'label': 'zysoong:zysoong/minor-improve-playwright-tool-output',
#    'ref': 'zysoong/minor-improve-playwright-tool-output',
#    'sha': '705be50e14d7b9dd8d986b0aef07a7833a8dd4c7',
#    'user': {'login': 'zysoong',
#     'id': 75294755,
#     'node_id': 'MDQ6VXNlcjc1Mjk0NzU1',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/75294755?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/zysoong',
#     'html_url': 'https://github.com/zysoong',
#     'followers_url': 'https://api.github.com/users/zysoong/followers',
#     'following_url': 'https://api.github.com/users/zysoong/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/zysoong/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/zysoong/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/zysoong/subscriptions',
#     'organizations_url': 'https://api.github.com/users/zysoong/orgs',
#     'repos_url': 'https://api.github.com/users/zysoong/repos',
#     'events_url': 'https://api.github.com/users/zysoong/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/zysoong/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'repo': {'id': 843760110,
#     'node_id': 'R_kgDOMkrB7g',
#     'name': 'langchain',
#     'full_name': 'zysoong/langchain',
#     'private': False,
#     'owner': {'login': 'zysoong',
#      'id': 75294755,
#      'node_id': 'MDQ6VXNlcjc1Mjk0NzU1',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/75294755?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/zysoong',
#      'html_url': 'https://github.com/zysoong',
#      'followers_url': 'https://api.github.com/users/zysoong/followers',
#      'following_url': 'https://api.github.com/users/zysoong/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/zysoong/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/zysoong/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/zysoong/subscriptions',
#      'organizations_url': 'https://api.github.com/users/zysoong/orgs',
#      'repos_url': 'https://api.github.com/users/zysoong/repos',
#      'events_url': 'https://api.github.com/users/zysoong/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/zysoong/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'html_url': 'https://github.com/zysoong/langchain',
#     'description': '🦜🔗 Build context-aware reasoning applications',
#     'fork': True,
#     'url': 'https://api.github.com/repos/zysoong/langchain',
#     'forks_url': 'https://api.github.com/repos/zysoong/langchain/forks',
#     'keys_url': 'https://api.github.com/repos/zysoong/langchain/keys{/key_id}',
#     'collaborators_url': 'https://api.github.com/repos/zysoong/langchain/collaborators{/collaborator}',
#     'teams_url': 'https://api.github.com/repos/zysoong/langchain/teams',
#     'hooks_url': 'https://api.github.com/repos/zysoong/langchain/hooks',
#     'issue_events_url': 'https://api.github.com/repos/zysoong/langchain/issues/events{/number}',
#     'events_url': 'https://api.github.com/repos/zysoong/langchain/events',
#     'assignees_url': 'https://api.github.com/repos/zysoong/langchain/assignees{/user}',
#     'branches_url': 'https://api.github.com/repos/zysoong/langchain/branches{/branch}',
#     'tags_url': 'https://api.github.com/repos/zysoong/langchain/tags',
#     'blobs_url': 'https://api.github.com/repos/zysoong/langchain/git/blobs{/sha}',
#     'git_tags_url': 'https://api.github.com/repos/zysoong/langchain/git/tags{/sha}',
#     'git_refs_url': 'https://api.github.com/repos/zysoong/langchain/git/refs{/sha}',
#     'trees_url': 'https://api.github.com/repos/zysoong/langchain/git/trees{/sha}',
#     'statuses_url': 'https://api.github.com/repos/zysoong/langchain/statuses/{sha}',
#     'languages_url': 'https://api.github.com/repos/zysoong/langchain/languages',
#     'stargazers_url': 'https://api.github.com/repos/zysoong/langchain/stargazers',
#     'contributors_url': 'https://api.github.com/repos/zysoong/langchain/contributors',
#     'subscribers_url': 'https://api.github.com/repos/zysoong/langchain/subscribers',
#     'subscription_url': 'https://api.github.com/repos/zysoong/langchain/subscription',
#     'commits_url': 'https://api.github.com/repos/zysoong/langchain/commits{/sha}',
#     'git_commits_url': 'https://api.github.com/repos/zysoong/langchain/git/commits{/sha}',
#     'comments_url': 'https://api.github.com/repos/zysoong/langchain/comments{/number}',
#     'issue_comment_url': 'https://api.github.com/repos/zysoong/langchain/issues/comments{/number}',
#     'contents_url': 'https://api.github.com/repos/zysoong/langchain/contents/{+path}',
#     'compare_url': 'https://api.github.com/repos/zysoong/langchain/compare/{base}...{head}',
#     'merges_url': 'https://api.github.com/repos/zysoong/langchain/merges',
#     'archive_url': 'https://api.github.com/repos/zysoong/langchain/{archive_format}{/ref}',
#     'downloads_url': 'https://api.github.com/repos/zysoong/langchain/downloads',
#     'issues_url': 'https://api.github.com/repos/zysoong/langchain/issues{/number}',
#     'pulls_url': 'https://api.github.com/repos/zysoong/langchain/pulls{/number}',
#     'milestones_url': 'https://api.github.com/repos/zysoong/langchain/milestones{/number}',
#     'notifications_url': 'https://api.github.com/repos/zysoong/langchain/notifications{?since,all,participating}',
#     'labels_url': 'https://api.github.com/repos/zysoong/langchain/labels{/name}',
#     'releases_url': 'https://api.github.com/repos/zysoong/langchain/releases{/id}',
#     'deployments_url': 'https://api.github.com/repos/zysoong/langchain/deployments',
#     'created_at': '2024-08-17T10:36:33Z',
#     'updated_at': '2024-08-24T22:54:06Z',
#     'pushed_at': '2024-08-24T23:00:35Z',
#     'git_url': 'git://github.com/zysoong/langchain.git',
#     'ssh_url': 'git@github.com:zysoong/langchain.git',
#     'clone_url': 'https://github.com/zysoong/langchain.git',
#     'svn_url': 'https://github.com/zysoong/langchain',
#     'homepage': 'https://python.langchain.com',
#     'size': 237085,
#     'stargazers_count': 0,
#     'watchers_count': 0,
#     'language': 'Jupyter Notebook',
#     'has_issues': False,
#     'has_projects': True,
#     'has_downloads': True,
#     'has_wiki': True,
#     'has_pages': False,
#     'has_discussions': False,
#     'forks_count': 0,
#     'mirror_url': None,
#     'archived': False,
#     'disabled': False,
#     'open_issues_count': 0,
#     'license': {'key': 'mit',
#      'name': 'MIT License',
#      'spdx_id': 'MIT',
#      'url': 'https://api.github.com/licenses/mit',
#      'node_id': 'MDc6TGljZW5zZTEz'},
#     'allow_forking': True,
#     'is_template': False,
#     'web_commit_signoff_required': False,
#     'topics': [],
#     'visibility': 'public',
#     'forks': 0,
#     'open_issues': 0,
#     'watchers': 0,
#     'default_branch': 'master'}},
#   'base': {'label': 'langchain-ai:master',
#    'ref': 'master',
#    'sha': '038c287b3a17d10da1000c7b5827ca7dc6d560a5',
#    'user': {'login': 'langchain-ai',
#     'id': 126733545,
#     'node_id': 'O_kgDOB43M6Q',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/126733545?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/langchain-ai',
#     'html_url': 'https://github.com/langchain-ai',
#     'followers_url': 'https://api.github.com/users/langchain-ai/followers',
#     'following_url': 'https://api.github.com/users/langchain-ai/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/langchain-ai/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/langchain-ai/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/langchain-ai/subscriptions',
#     'organizations_url': 'https://api.github.com/users/langchain-ai/orgs',
#     'repos_url': 'https://api.github.com/users/langchain-ai/repos',
#     'events_url': 'https://api.github.com/users/langchain-ai/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/langchain-ai/received_events',
#     'type': 'Organization',
#     'site_admin': False},
#    'repo': {'id': 552661142,
#     'node_id': 'R_kgDOIPDwlg',
#     'name': 'langchain',
#     'full_name': 'langchain-ai/langchain',
#     'private': False,
#     'owner': {'login': 'langchain-ai',
#      'id': 126733545,
#      'node_id': 'O_kgDOB43M6Q',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/126733545?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/langchain-ai',
#      'html_url': 'https://github.com/langchain-ai',
#      'followers_url': 'https://api.github.com/users/langchain-ai/followers',
#      'following_url': 'https://api.github.com/users/langchain-ai/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/langchain-ai/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/langchain-ai/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/langchain-ai/subscriptions',
#      'organizations_url': 'https://api.github.com/users/langchain-ai/orgs',
#      'repos_url': 'https://api.github.com/users/langchain-ai/repos',
#      'events_url': 'https://api.github.com/users/langchain-ai/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/langchain-ai/received_events',
#      'type': 'Organization',
#      'site_admin': False},
#     'html_url': 'https://github.com/langchain-ai/langchain',
#     'description': '🦜🔗 Build context-aware reasoning applications',
#     'fork': False,
#     'url': 'https://api.github.com/repos/langchain-ai/langchain',
#     'forks_url': 'https://api.github.com/repos/langchain-ai/langchain/forks',
#     'keys_url': 'https://api.github.com/repos/langchain-ai/langchain/keys{/key_id}',
#     'collaborators_url': 'https://api.github.com/repos/langchain-ai/langchain/collaborators{/collaborator}',
#     'teams_url': 'https://api.github.com/repos/langchain-ai/langchain/teams',
#     'hooks_url': 'https://api.github.com/repos/langchain-ai/langchain/hooks',
#     'issue_events_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/events{/number}',
#     'events_url': 'https://api.github.com/repos/langchain-ai/langchain/events',
#     'assignees_url': 'https://api.github.com/repos/langchain-ai/langchain/assignees{/user}',
#     'branches_url': 'https://api.github.com/repos/langchain-ai/langchain/branches{/branch}',
#     'tags_url': 'https://api.github.com/repos/langchain-ai/langchain/tags',
#     'blobs_url': 'https://api.github.com/repos/langchain-ai/langchain/git/blobs{/sha}',
#     'git_tags_url': 'https://api.github.com/repos/langchain-ai/langchain/git/tags{/sha}',
#     'git_refs_url': 'https://api.github.com/repos/langchain-ai/langchain/git/refs{/sha}',
#     'trees_url': 'https://api.github.com/repos/langchain-ai/langchain/git/trees{/sha}',
#     'statuses_url': 'https://api.github.com/repos/langchain-ai/langchain/statuses/{sha}',
#     'languages_url': 'https://api.github.com/repos/langchain-ai/langchain/languages',
#     'stargazers_url': 'https://api.github.com/repos/langchain-ai/langchain/stargazers',
#     'contributors_url': 'https://api.github.com/repos/langchain-ai/langchain/contributors',
#     'subscribers_url': 'https://api.github.com/repos/langchain-ai/langchain/subscribers',
#     'subscription_url': 'https://api.github.com/repos/langchain-ai/langchain/subscription',
#     'commits_url': 'https://api.github.com/repos/langchain-ai/langchain/commits{/sha}',
#     'git_commits_url': 'https://api.github.com/repos/langchain-ai/langchain/git/commits{/sha}',
#     'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/comments{/number}',
#     'issue_comment_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/comments{/number}',
#     'contents_url': 'https://api.github.com/repos/langchain-ai/langchain/contents/{+path}',
#     'compare_url': 'https://api.github.com/repos/langchain-ai/langchain/compare/{base}...{head}',
#     'merges_url': 'https://api.github.com/repos/langchain-ai/langchain/merges',
#     'archive_url': 'https://api.github.com/repos/langchain-ai/langchain/{archive_format}{/ref}',
#     'downloads_url': 'https://api.github.com/repos/langchain-ai/langchain/downloads',
#     'issues_url': 'https://api.github.com/repos/langchain-ai/langchain/issues{/number}',
#     'pulls_url': 'https://api.github.com/repos/langchain-ai/langchain/pulls{/number}',
#     'milestones_url': 'https://api.github.com/repos/langchain-ai/langchain/milestones{/number}',
#     'notifications_url': 'https://api.github.com/repos/langchain-ai/langchain/notifications{?since,all,participating}',
#     'labels_url': 'https://api.github.com/repos/langchain-ai/langchain/labels{/name}',
#     'releases_url': 'https://api.github.com/repos/langchain-ai/langchain/releases{/id}',
#     'deployments_url': 'https://api.github.com/repos/langchain-ai/langchain/deployments',
#     'created_at': '2022-10-17T02:58:36Z',
#     'updated_at': '2024-08-25T02:02:41Z',
#     'pushed_at': '2024-08-24T23:07:26Z',
#     'git_url': 'git://github.com/langchain-ai/langchain.git',
#     'ssh_url': 'git@github.com:langchain-ai/langchain.git',
#     'clone_url': 'https://github.com/langchain-ai/langchain.git',
#     'svn_url': 'https://github.com/langchain-ai/langchain',
#     'homepage': 'https://python.langchain.com',
#     'size': 290361,
#     'stargazers_count': 91185,
#     'watchers_count': 91185,
#     'language': 'Jupyter Notebook',
#     'has_issues': True,
#     'has_projects': True,
#     'has_downloads': True,
#     'has_wiki': True,
#     'has_pages': False,
#     'has_discussions': True,
#     'forks_count': 14493,
#     'mirror_url': None,
#     'archived': False,
#     'disabled': False,
#     'open_issues_count': 898,
#     'license': {'key': 'mit',
#      'name': 'MIT License',
#      'spdx_id': 'MIT',
#      'url': 'https://api.github.com/licenses/mit',
#      'node_id': 'MDc6TGljZW5zZTEz'},
#     'allow_forking': True,
#     'is_template': False,
#     'web_commit_signoff_required': False,
#     'topics': [],
#     'visibility': 'public',
#     'forks': 14493,
#     'open_issues': 898,
#     'watchers': 91185,
#     'default_branch': 'master'}},
#   '_links': {'self': {'href': 'https://api.github.com/repos/langchain-ai/langchain/pulls/25728'},
#    'html': {'href': 'https://github.com/langchain-ai/langchain/pull/25728'},
#    'issue': {'href': 'https://api.github.com/repos/langchain-ai/langchain/issues/25728'},
#    'comments': {'href': 'https://api.github.com/repos/langchain-ai/langchain/issues/25728/comments'},
#    'review_comments': {'href': 'https://api.github.com/repos/langchain-ai/langchain/pulls/25728/comments'},
#    'review_comment': {'href': 'https://api.github.com/repos/langchain-ai/langchain/pulls/comments{/number}'},
#    'commits': {'href': 'https://api.github.com/repos/langchain-ai/langchain/pulls/25728/commits'},
#    'statuses': {'href': 'https://api.github.com/repos/langchain-ai/langchain/statuses/705be50e14d7b9dd8d986b0aef07a7833a8dd4c7'}},
#   'author_association': 'NONE',
#   'auto_merge': None,
#   'active_lock_reason': None},
#  {'url': 'https://api.github.com/repos/langchain-ai/langchain/pulls/25727',
#   'id': 2035693773,
#   'node_id': 'PR_kwDOIPDwls55VjjN',
#   'html_url': 'https://github.com/langchain-ai/langchain/pull/25727',
#   'diff_url': 'https://github.com/langchain-ai/langchain/pull/25727.diff',
#   'patch_url': 'https://github.com/langchain-ai/langchain/pull/25727.patch',
#   'issue_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25727',
#   'number': 25727,
#   'state': 'open',
#   'locked': False,
#   'title': 'community: fix model initialization bug for deepinfra',
#   'user': {'login': 'mo374z',
#    'id': 87517800,
#    'node_id': 'MDQ6VXNlcjg3NTE3ODAw',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/87517800?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mo374z',
#    'html_url': 'https://github.com/mo374z',
#    'followers_url': 'https://api.github.com/users/mo374z/followers',
#    'following_url': 'https://api.github.com/users/mo374z/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/mo374z/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/mo374z/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/mo374z/subscriptions',
#    'organizations_url': 'https://api.github.com/users/mo374z/orgs',
#    'repos_url': 'https://api.github.com/users/mo374z/repos',
#    'events_url': 'https://api.github.com/users/mo374z/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/mo374z/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'body': '### Description\r\nadds an init method to ChatDeepInfra to set the model_name attribute accordings to the argument\r\n### Issue\r\ncurrently, the model_name specified by the user during initialization of the ChatDeepInfra class is never set. Therefore, it always chooses the default model (meta-llama/Llama-2-70b-chat-hf, however probably since this is deprecated it always uses meta-llama/Llama-3-70b-Instruct). We stumbled across this issue and fixed it as proposed in this pull request. Feel free to change the fix according to your coding guidelines and style, this is just a proposal and we want to draw attention to this problem.\r\n### Dependencies\r\nno additional dependencies required\r\n\r\nFeel free to contact me or @timo282 and @finitearth if you have any questions.',
#   'created_at': '2024-08-24T21:01:08Z',
#   'updated_at': '2024-08-24T21:11:55Z',
#   'closed_at': None,
#   'merged_at': None,
#   'merge_commit_sha': '4b74b5020171f67fe83aaf096448b111816057ba',
#   'assignee': None,
#   'assignees': [],
#   'requested_reviewers': [],
#   'requested_teams': [],
#   'labels': [{'id': 5680700839,
#     'node_id': 'LA_kwDOIPDwls8AAAABUpidpw',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/%F0%9F%A4%96:bug',
#     'name': '🤖:bug',
#     'color': 'F9D0C4',
#     'default': False,
#     'description': 'Related to a bug, vulnerability, unexpected error with an existing feature'},
#    {'id': 6232714104,
#     'node_id': 'LA_kwDOIPDwls8AAAABc3-reA',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/size:XS',
#     'name': 'size:XS',
#     'color': 'C2E0C6',
#     'default': False,
#     'description': 'This PR changes 0-9 lines, ignoring generated files.'},
#    {'id': 7097373342,
#     'node_id': 'LA_kwDOIPDwls8AAAABpwlSng',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/community',
#     'name': 'community',
#     'color': '579082',
#     'default': False,
#     'description': 'Related to langchain-community'}],
#   'milestone': None,
#   'draft': False,
#   'commits_url': 'https://api.github.com/repos/langchain-ai/langchain/pulls/25727/commits',
#   'review_comments_url': 'https://api.github.com/repos/langchain-ai/langchain/pulls/25727/comments',
#   'review_comment_url': 'https://api.github.com/repos/langchain-ai/langchain/pulls/comments{/number}',
#   'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25727/comments',
#   'statuses_url': 'https://api.github.com/repos/langchain-ai/langchain/statuses/ed56d907748c58b9eeddd9387cf8456b276450bd',
#   'head': {'label': 'mo374z:master',
#    'ref': 'master',
#    'sha': 'ed56d907748c58b9eeddd9387cf8456b276450bd',
#    'user': {'login': 'mo374z',
#     'id': 87517800,
#     'node_id': 'MDQ6VXNlcjg3NTE3ODAw',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/87517800?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/mo374z',
#     'html_url': 'https://github.com/mo374z',
#     'followers_url': 'https://api.github.com/users/mo374z/followers',
#     'following_url': 'https://api.github.com/users/mo374z/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/mo374z/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/mo374z/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/mo374z/subscriptions',
#     'organizations_url': 'https://api.github.com/users/mo374z/orgs',
#     'repos_url': 'https://api.github.com/users/mo374z/repos',
#     'events_url': 'https://api.github.com/users/mo374z/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/mo374z/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'repo': {'id': 846928308,
#     'node_id': 'R_kgDOMnsZtA',
#     'name': 'langchain',
#     'full_name': 'mo374z/langchain',
#     'private': False,
#     'owner': {'login': 'mo374z',
#      'id': 87517800,
#      'node_id': 'MDQ6VXNlcjg3NTE3ODAw',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/87517800?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/mo374z',
#      'html_url': 'https://github.com/mo374z',
#      'followers_url': 'https://api.github.com/users/mo374z/followers',
#      'following_url': 'https://api.github.com/users/mo374z/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/mo374z/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/mo374z/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/mo374z/subscriptions',
#      'organizations_url': 'https://api.github.com/users/mo374z/orgs',
#      'repos_url': 'https://api.github.com/users/mo374z/repos',
#      'events_url': 'https://api.github.com/users/mo374z/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/mo374z/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'html_url': 'https://github.com/mo374z/langchain',
#     'description': '🦜🔗 Build context-aware reasoning applications',
#     'fork': True,
#     'url': 'https://api.github.com/repos/mo374z/langchain',
#     'forks_url': 'https://api.github.com/repos/mo374z/langchain/forks',
#     'keys_url': 'https://api.github.com/repos/mo374z/langchain/keys{/key_id}',
#     'collaborators_url': 'https://api.github.com/repos/mo374z/langchain/collaborators{/collaborator}',
#     'teams_url': 'https://api.github.com/repos/mo374z/langchain/teams',
#     'hooks_url': 'https://api.github.com/repos/mo374z/langchain/hooks',
#     'issue_events_url': 'https://api.github.com/repos/mo374z/langchain/issues/events{/number}',
#     'events_url': 'https://api.github.com/repos/mo374z/langchain/events',
#     'assignees_url': 'https://api.github.com/repos/mo374z/langchain/assignees{/user}',
#     'branches_url': 'https://api.github.com/repos/mo374z/langchain/branches{/branch}',
#     'tags_url': 'https://api.github.com/repos/mo374z/langchain/tags',
#     'blobs_url': 'https://api.github.com/repos/mo374z/langchain/git/blobs{/sha}',
#     'git_tags_url': 'https://api.github.com/repos/mo374z/langchain/git/tags{/sha}',
#     'git_refs_url': 'https://api.github.com/repos/mo374z/langchain/git/refs{/sha}',
#     'trees_url': 'https://api.github.com/repos/mo374z/langchain/git/trees{/sha}',
#     'statuses_url': 'https://api.github.com/repos/mo374z/langchain/statuses/{sha}',
#     'languages_url': 'https://api.github.com/repos/mo374z/langchain/languages',
#     'stargazers_url': 'https://api.github.com/repos/mo374z/langchain/stargazers',
#     'contributors_url': 'https://api.github.com/repos/mo374z/langchain/contributors',
#     'subscribers_url': 'https://api.github.com/repos/mo374z/langchain/subscribers',
#     'subscription_url': 'https://api.github.com/repos/mo374z/langchain/subscription',
#     'commits_url': 'https://api.github.com/repos/mo374z/langchain/commits{/sha}',
#     'git_commits_url': 'https://api.github.com/repos/mo374z/langchain/git/commits{/sha}',
#     'comments_url': 'https://api.github.com/repos/mo374z/langchain/comments{/number}',
#     'issue_comment_url': 'https://api.github.com/repos/mo374z/langchain/issues/comments{/number}',
#     'contents_url': 'https://api.github.com/repos/mo374z/langchain/contents/{+path}',
#     'compare_url': 'https://api.github.com/repos/mo374z/langchain/compare/{base}...{head}',
#     'merges_url': 'https://api.github.com/repos/mo374z/langchain/merges',
#     'archive_url': 'https://api.github.com/repos/mo374z/langchain/{archive_format}{/ref}',
#     'downloads_url': 'https://api.github.com/repos/mo374z/langchain/downloads',
#     'issues_url': 'https://api.github.com/repos/mo374z/langchain/issues{/number}',
#     'pulls_url': 'https://api.github.com/repos/mo374z/langchain/pulls{/number}',
#     'milestones_url': 'https://api.github.com/repos/mo374z/langchain/milestones{/number}',
#     'notifications_url': 'https://api.github.com/repos/mo374z/langchain/notifications{?since,all,participating}',
#     'labels_url': 'https://api.github.com/repos/mo374z/langchain/labels{/name}',
#     'releases_url': 'https://api.github.com/repos/mo374z/langchain/releases{/id}',
#     'deployments_url': 'https://api.github.com/repos/mo374z/langchain/deployments',
#     'created_at': '2024-08-24T10:58:10Z',
#     'updated_at': '2024-08-24T20:47:20Z',
#     'pushed_at': '2024-08-24T20:47:04Z',
#     'git_url': 'git://github.com/mo374z/langchain.git',
#     'ssh_url': 'git@github.com:mo374z/langchain.git',
#     'clone_url': 'https://github.com/mo374z/langchain.git',
#     'svn_url': 'https://github.com/mo374z/langchain',
#     'homepage': 'https://python.langchain.com',
#     'size': 237046,
#     'stargazers_count': 0,
#     'watchers_count': 0,
#     'language': 'Jupyter Notebook',
#     'has_issues': False,
#     'has_projects': True,
#     'has_downloads': True,
#     'has_wiki': True,
#     'has_pages': False,
#     'has_discussions': False,
#     'forks_count': 0,
#     'mirror_url': None,
#     'archived': False,
#     'disabled': False,
#     'open_issues_count': 0,
#     'license': {'key': 'mit',
#      'name': 'MIT License',
#      'spdx_id': 'MIT',
#      'url': 'https://api.github.com/licenses/mit',
#      'node_id': 'MDc6TGljZW5zZTEz'},
#     'allow_forking': True,
#     'is_template': False,
#     'web_commit_signoff_required': False,
#     'topics': [],
#     'visibility': 'public',
#     'forks': 0,
#     'open_issues': 0,
#     'watchers': 0,
#     'default_branch': 'master'}},
#   'base': {'label': 'langchain-ai:master',
#    'ref': 'master',
#    'sha': '038c287b3a17d10da1000c7b5827ca7dc6d560a5',
#    'user': {'login': 'langchain-ai',
#     'id': 126733545,
#     'node_id': 'O_kgDOB43M6Q',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/126733545?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/langchain-ai',
#     'html_url': 'https://github.com/langchain-ai',
#     'followers_url': 'https://api.github.com/users/langchain-ai/followers',
# ...
#     'node_id': 'LA_kwDOIPDwls8AAAABsY_WnQ',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/0.3%20prep',
#     'name': '0.3 prep',
#     'color': 'E3834B',
#     'default': False,
#     'description': 'Work done for 0.3 prep'}],
#   'milestone': None,
#   'draft': True,
#   'commits_url': 'https://api.github.com/repos/langchain-ai/langchain/pulls/25503/commits',
#   'review_comments_url': 'https://api.github.com/repos/langchain-ai/langchain/pulls/25503/comments',
#   'review_comment_url': 'https://api.github.com/repos/langchain-ai/langchain/pulls/comments{/number}',
#   'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25503/comments',
#   'statuses_url': 'https://api.github.com/repos/langchain-ai/langchain/statuses/1f97962e1032255bab02ae42ef2b1eed04b5a435',
#   'head': {'label': 'langchain-ai:eugene/openai_0.3',
#    'ref': 'eugene/openai_0.3',
#    'sha': '1f97962e1032255bab02ae42ef2b1eed04b5a435',
#    'user': {'login': 'langchain-ai',
#     'id': 126733545,
#     'node_id': 'O_kgDOB43M6Q',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/126733545?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/langchain-ai',
#     'html_url': 'https://github.com/langchain-ai',
#     'followers_url': 'https://api.github.com/users/langchain-ai/followers',
#     'following_url': 'https://api.github.com/users/langchain-ai/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/langchain-ai/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/langchain-ai/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/langchain-ai/subscriptions',
#     'organizations_url': 'https://api.github.com/users/langchain-ai/orgs',
#     'repos_url': 'https://api.github.com/users/langchain-ai/repos',
#     'events_url': 'https://api.github.com/users/langchain-ai/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/langchain-ai/received_events',
#     'type': 'Organization',
#     'site_admin': False},
#    'repo': {'id': 552661142,
#     'node_id': 'R_kgDOIPDwlg',
#     'name': 'langchain',
#     'full_name': 'langchain-ai/langchain',
#     'private': False,
#     'owner': {'login': 'langchain-ai',
#      'id': 126733545,
#      'node_id': 'O_kgDOB43M6Q',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/126733545?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/langchain-ai',
#      'html_url': 'https://github.com/langchain-ai',
#      'followers_url': 'https://api.github.com/users/langchain-ai/followers',
#      'following_url': 'https://api.github.com/users/langchain-ai/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/langchain-ai/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/langchain-ai/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/langchain-ai/subscriptions',
#      'organizations_url': 'https://api.github.com/users/langchain-ai/orgs',
#      'repos_url': 'https://api.github.com/users/langchain-ai/repos',
#      'events_url': 'https://api.github.com/users/langchain-ai/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/langchain-ai/received_events',
#      'type': 'Organization',
#      'site_admin': False},
#     'html_url': 'https://github.com/langchain-ai/langchain',
#     'description': '🦜🔗 Build context-aware reasoning applications',
#     'fork': False,
#     'url': 'https://api.github.com/repos/langchain-ai/langchain',
#     'forks_url': 'https://api.github.com/repos/langchain-ai/langchain/forks',
#     'keys_url': 'https://api.github.com/repos/langchain-ai/langchain/keys{/key_id}',
#     'collaborators_url': 'https://api.github.com/repos/langchain-ai/langchain/collaborators{/collaborator}',
#     'teams_url': 'https://api.github.com/repos/langchain-ai/langchain/teams',
#     'hooks_url': 'https://api.github.com/repos/langchain-ai/langchain/hooks',
#     'issue_events_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/events{/number}',
#     'events_url': 'https://api.github.com/repos/langchain-ai/langchain/events',
#     'assignees_url': 'https://api.github.com/repos/langchain-ai/langchain/assignees{/user}',
#     'branches_url': 'https://api.github.com/repos/langchain-ai/langchain/branches{/branch}',
#     'tags_url': 'https://api.github.com/repos/langchain-ai/langchain/tags',
#     'blobs_url': 'https://api.github.com/repos/langchain-ai/langchain/git/blobs{/sha}',
#     'git_tags_url': 'https://api.github.com/repos/langchain-ai/langchain/git/tags{/sha}',
#     'git_refs_url': 'https://api.github.com/repos/langchain-ai/langchain/git/refs{/sha}',
#     'trees_url': 'https://api.github.com/repos/langchain-ai/langchain/git/trees{/sha}',
#     'statuses_url': 'https://api.github.com/repos/langchain-ai/langchain/statuses/{sha}',
#     'languages_url': 'https://api.github.com/repos/langchain-ai/langchain/languages',
#     'stargazers_url': 'https://api.github.com/repos/langchain-ai/langchain/stargazers',
#     'contributors_url': 'https://api.github.com/repos/langchain-ai/langchain/contributors',
#     'subscribers_url': 'https://api.github.com/repos/langchain-ai/langchain/subscribers',
#     'subscription_url': 'https://api.github.com/repos/langchain-ai/langchain/subscription',
#     'commits_url': 'https://api.github.com/repos/langchain-ai/langchain/commits{/sha}',
#     'git_commits_url': 'https://api.github.com/repos/langchain-ai/langchain/git/commits{/sha}',
#     'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/comments{/number}',
#     'issue_comment_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/comments{/number}',
#     'contents_url': 'https://api.github.com/repos/langchain-ai/langchain/contents/{+path}',
#     'compare_url': 'https://api.github.com/repos/langchain-ai/langchain/compare/{base}...{head}',
#     'merges_url': 'https://api.github.com/repos/langchain-ai/langchain/merges',
#     'archive_url': 'https://api.github.com/repos/langchain-ai/langchain/{archive_format}{/ref}',
#     'downloads_url': 'https://api.github.com/repos/langchain-ai/langchain/downloads',
#     'issues_url': 'https://api.github.com/repos/langchain-ai/langchain/issues{/number}',
#     'pulls_url': 'https://api.github.com/repos/langchain-ai/langchain/pulls{/number}',
#     'milestones_url': 'https://api.github.com/repos/langchain-ai/langchain/milestones{/number}',
#     'notifications_url': 'https://api.github.com/repos/langchain-ai/langchain/notifications{?since,all,participating}',
#     'labels_url': 'https://api.github.com/repos/langchain-ai/langchain/labels{/name}',
#     'releases_url': 'https://api.github.com/repos/langchain-ai/langchain/releases{/id}',
#     'deployments_url': 'https://api.github.com/repos/langchain-ai/langchain/deployments',
#     'created_at': '2022-10-17T02:58:36Z',
#     'updated_at': '2024-08-25T02:02:41Z',
#     'pushed_at': '2024-08-24T23:07:26Z',
#     'git_url': 'git://github.com/langchain-ai/langchain.git',
#     'ssh_url': 'git@github.com:langchain-ai/langchain.git',
#     'clone_url': 'https://github.com/langchain-ai/langchain.git',
#     'svn_url': 'https://github.com/langchain-ai/langchain',
#     'homepage': 'https://python.langchain.com',
#     'size': 290361,
#     'stargazers_count': 91185,
#     'watchers_count': 91185,
#     'language': 'Jupyter Notebook',
#     'has_issues': True,
#     'has_projects': True,
#     'has_downloads': True,
#     'has_wiki': True,
#     'has_pages': False,
#     'has_discussions': True,
#     'forks_count': 14493,
#     'mirror_url': None,
#     'archived': False,
#     'disabled': False,
#     'open_issues_count': 898,
#     'license': {'key': 'mit',
#      'name': 'MIT License',
#      'spdx_id': 'MIT',
#      'url': 'https://api.github.com/licenses/mit',
#      'node_id': 'MDc6TGljZW5zZTEz'},
#     'allow_forking': True,
#     'is_template': False,
#     'web_commit_signoff_required': False,
#     'topics': [],
#     'visibility': 'public',
#     'forks': 14493,
#     'open_issues': 898,
#     'watchers': 91185,
#     'default_branch': 'master'}},
#   'base': {'label': 'langchain-ai:master',
#    'ref': 'master',
#    'sha': 'a06818a6543793e1b21f5896135244949e02c8e1',
#    'user': {'login': 'langchain-ai',
#     'id': 126733545,
#     'node_id': 'O_kgDOB43M6Q',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/126733545?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/langchain-ai',
#     'html_url': 'https://github.com/langchain-ai',
#     'followers_url': 'https://api.github.com/users/langchain-ai/followers',
#     'following_url': 'https://api.github.com/users/langchain-ai/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/langchain-ai/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/langchain-ai/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/langchain-ai/subscriptions',
#     'organizations_url': 'https://api.github.com/users/langchain-ai/orgs',
#     'repos_url': 'https://api.github.com/users/langchain-ai/repos',
#     'events_url': 'https://api.github.com/users/langchain-ai/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/langchain-ai/received_events',
#     'type': 'Organization',
#     'site_admin': False},
#    'repo': {'id': 552661142,
#     'node_id': 'R_kgDOIPDwlg',
#     'name': 'langchain',
#     'full_name': 'langchain-ai/langchain',
#     'private': False,
#     'owner': {'login': 'langchain-ai',
#      'id': 126733545,
#      'node_id': 'O_kgDOB43M6Q',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/126733545?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/langchain-ai',
#      'html_url': 'https://github.com/langchain-ai',
#      'followers_url': 'https://api.github.com/users/langchain-ai/followers',
#      'following_url': 'https://api.github.com/users/langchain-ai/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/langchain-ai/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/langchain-ai/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/langchain-ai/subscriptions',
#      'organizations_url': 'https://api.github.com/users/langchain-ai/orgs',
#      'repos_url': 'https://api.github.com/users/langchain-ai/repos',
#      'events_url': 'https://api.github.com/users/langchain-ai/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/langchain-ai/received_events',
#      'type': 'Organization',
#      'site_admin': False},
#     'html_url': 'https://github.com/langchain-ai/langchain',
#     'description': '🦜🔗 Build context-aware reasoning applications',
#     'fork': False,
#     'url': 'https://api.github.com/repos/langchain-ai/langchain',
#     'forks_url': 'https://api.github.com/repos/langchain-ai/langchain/forks',
#     'keys_url': 'https://api.github.com/repos/langchain-ai/langchain/keys{/key_id}',
#     'collaborators_url': 'https://api.github.com/repos/langchain-ai/langchain/collaborators{/collaborator}',
#     'teams_url': 'https://api.github.com/repos/langchain-ai/langchain/teams',
#     'hooks_url': 'https://api.github.com/repos/langchain-ai/langchain/hooks',
#     'issue_events_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/events{/number}',
#     'events_url': 'https://api.github.com/repos/langchain-ai/langchain/events',
#     'assignees_url': 'https://api.github.com/repos/langchain-ai/langchain/assignees{/user}',
#     'branches_url': 'https://api.github.com/repos/langchain-ai/langchain/branches{/branch}',
#     'tags_url': 'https://api.github.com/repos/langchain-ai/langchain/tags',
#     'blobs_url': 'https://api.github.com/repos/langchain-ai/langchain/git/blobs{/sha}',
#     'git_tags_url': 'https://api.github.com/repos/langchain-ai/langchain/git/tags{/sha}',
#     'git_refs_url': 'https://api.github.com/repos/langchain-ai/langchain/git/refs{/sha}',
#     'trees_url': 'https://api.github.com/repos/langchain-ai/langchain/git/trees{/sha}',
#     'statuses_url': 'https://api.github.com/repos/langchain-ai/langchain/statuses/{sha}',
#     'languages_url': 'https://api.github.com/repos/langchain-ai/langchain/languages',
#     'stargazers_url': 'https://api.github.com/repos/langchain-ai/langchain/stargazers',
#     'contributors_url': 'https://api.github.com/repos/langchain-ai/langchain/contributors',
#     'subscribers_url': 'https://api.github.com/repos/langchain-ai/langchain/subscribers',
#     'subscription_url': 'https://api.github.com/repos/langchain-ai/langchain/subscription',
#     'commits_url': 'https://api.github.com/repos/langchain-ai/langchain/commits{/sha}',
#     'git_commits_url': 'https://api.github.com/repos/langchain-ai/langchain/git/commits{/sha}',
#     'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/comments{/number}',
#     'issue_comment_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/comments{/number}',
#     'contents_url': 'https://api.github.com/repos/langchain-ai/langchain/contents/{+path}',
#     'compare_url': 'https://api.github.com/repos/langchain-ai/langchain/compare/{base}...{head}',
#     'merges_url': 'https://api.github.com/repos/langchain-ai/langchain/merges',
#     'archive_url': 'https://api.github.com/repos/langchain-ai/langchain/{archive_format}{/ref}',
#     'downloads_url': 'https://api.github.com/repos/langchain-ai/langchain/downloads',
#     'issues_url': 'https://api.github.com/repos/langchain-ai/langchain/issues{/number}',
#     'pulls_url': 'https://api.github.com/repos/langchain-ai/langchain/pulls{/number}',
#     'milestones_url': 'https://api.github.com/repos/langchain-ai/langchain/milestones{/number}',
#     'notifications_url': 'https://api.github.com/repos/langchain-ai/langchain/notifications{?since,all,participating}',
#     'labels_url': 'https://api.github.com/repos/langchain-ai/langchain/labels{/name}',
#     'releases_url': 'https://api.github.com/repos/langchain-ai/langchain/releases{/id}',
#     'deployments_url': 'https://api.github.com/repos/langchain-ai/langchain/deployments',
#     'created_at': '2022-10-17T02:58:36Z',
#     'updated_at': '2024-08-25T02:02:41Z',
#     'pushed_at': '2024-08-24T23:07:26Z',
#     'git_url': 'git://github.com/langchain-ai/langchain.git',
#     'ssh_url': 'git@github.com:langchain-ai/langchain.git',
#     'clone_url': 'https://github.com/langchain-ai/langchain.git',
#     'svn_url': 'https://github.com/langchain-ai/langchain',
#     'homepage': 'https://python.langchain.com',
#     'size': 290361,
#     'stargazers_count': 91185,
#     'watchers_count': 91185,
#     'language': 'Jupyter Notebook',
#     'has_issues': True,
#     'has_projects': True,
#     'has_downloads': True,
#     'has_wiki': True,
#     'has_pages': False,
#     'has_discussions': True,
#     'forks_count': 14493,
#     'mirror_url': None,
#     'archived': False,
#     'disabled': False,
#     'open_issues_count': 898,
#     'license': {'key': 'mit',
#      'name': 'MIT License',
#      'spdx_id': 'MIT',
#      'url': 'https://api.github.com/licenses/mit',
#      'node_id': 'MDc6TGljZW5zZTEz'},
#     'allow_forking': True,
#     'is_template': False,
#     'web_commit_signoff_required': False,
#     'topics': [],
#     'visibility': 'public',
#     'forks': 14493,
#     'open_issues': 898,
#     'watchers': 91185,
#     'default_branch': 'master'}},
#   '_links': {'self': {'href': 'https://api.github.com/repos/langchain-ai/langchain/pulls/25503'},
#    'html': {'href': 'https://github.com/langchain-ai/langchain/pull/25503'},
#    'issue': {'href': 'https://api.github.com/repos/langchain-ai/langchain/issues/25503'},
#    'comments': {'href': 'https://api.github.com/repos/langchain-ai/langchain/issues/25503/comments'},
#    'review_comments': {'href': 'https://api.github.com/repos/langchain-ai/langchain/pulls/25503/comments'},
#    'review_comment': {'href': 'https://api.github.com/repos/langchain-ai/langchain/pulls/comments{/number}'},
#    'commits': {'href': 'https://api.github.com/repos/langchain-ai/langchain/pulls/25503/commits'},
#    'statuses': {'href': 'https://api.github.com/repos/langchain-ai/langchain/statuses/1f97962e1032255bab02ae42ef2b1eed04b5a435'}},
#   'author_association': 'COLLABORATOR',
#   'auto_merge': None,
#   'active_lock_reason': None}]

# %% [markdown]
# ### List Commits API
#
# API完整文档说明见：https://docs.github.com/en/rest/commits/commits?apiVersion=2022-11-28
#
# **请求样例**：`GET /repos/{owner}/{repo}/commits`;

# %%
commits = github_client.fetch_commits(repo)

# %%
commits
# Out:
# [{'sha': '038c287b3a17d10da1000c7b5827ca7dc6d560a5',
#   'node_id': 'C_kwDOIPDwltoAKDAzOGMyODdiM2ExN2QxMGRhMTAwMGM3YjU4MjdjYTdkYzZkNTYwYTU',
#   'commit': {'author': {'name': 'Christophe Bornet',
#     'email': 'cbornet@hotmail.com',
#     'date': '2024-08-24T01:23:52Z'},
#    'committer': {'name': 'GitHub',
#     'email': 'noreply@github.com',
#     'date': '2024-08-24T01:23:52Z'},
#    'message': 'all: Improve make lint command (#25344)\n\n* Removed `ruff check --select I` as `I` is already selected and checked\r\nin the main `ruff check` command\r\n* Added checks for non-empty `PYTHON_FILES`\r\n* Run `ruff check` only on `PYTHON_FILES`\r\n\r\nCo-authored-by: Erick Friis <erick@langchain.dev>',
#    'tree': {'sha': 'd80d952c07022684003ac58ddc0c6909a75426fc',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/git/trees/d80d952c07022684003ac58ddc0c6909a75426fc'},
#    'url': 'https://api.github.com/repos/langchain-ai/langchain/git/commits/038c287b3a17d10da1000c7b5827ca7dc6d560a5',
#    'comment_count': 0,
#    'verification': {'verified': True,
#     'reason': 'valid',
#     'signature': '-----BEGIN PGP SIGNATURE-----\n\\n6dNUGXEIGIWRLDrZVc39\n=f/xh\n-----END PGP SIGNATURE-----\n',
#     'payload': 'tree d80d952c07022684003ac58ddc0c6909a75426fc\nparent 9a29398fe629aa62fc5bc237ec20f8461a039f7f\nauthor Christophe Bornet <cbornet@hotmail.com> 1724462632 +0200\ncommitter GitHub <noreply@github.com> 1724462632 -0700\n\nall: Improve make lint command (#25344)\n\n* Removed `ruff check --select I` as `I` is already selected and checked\r\nin the main `ruff check` command\r\n* Added checks for non-empty `PYTHON_FILES`\r\n* Run `ruff check` only on `PYTHON_FILES`\r\n\r\nCo-authored-by: Erick Friis <erick@langchain.dev>'}},
#   'url': 'https://api.github.com/repos/langchain-ai/langchain/commits/038c287b3a17d10da1000c7b5827ca7dc6d560a5',
#   'html_url': 'https://github.com/langchain-ai/langchain/commit/038c287b3a17d10da1000c7b5827ca7dc6d560a5',
#   'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/commits/038c287b3a17d10da1000c7b5827ca7dc6d560a5/comments',
#   'author': {'login': 'cbornet',
#    'id': 11633333,
#    'node_id': 'MDQ6VXNlcjExNjMzMzMz',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/11633333?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/cbornet',
#    'html_url': 'https://github.com/cbornet',
#    'followers_url': 'https://api.github.com/users/cbornet/followers',
#    'following_url': 'https://api.github.com/users/cbornet/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/cbornet/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/cbornet/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/cbornet/subscriptions',
#    'organizations_url': 'https://api.github.com/users/cbornet/orgs',
#    'repos_url': 'https://api.github.com/users/cbornet/repos',
#    'events_url': 'https://api.github.com/users/cbornet/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/cbornet/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'committer': {'login': 'web-flow',
#    'id': 19864447,
#    'node_id': 'MDQ6VXNlcjE5ODY0NDQ3',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/19864447?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/web-flow',
#    'html_url': 'https://github.com/web-flow',
#    'followers_url': 'https://api.github.com/users/web-flow/followers',
#    'following_url': 'https://api.github.com/users/web-flow/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/web-flow/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/web-flow/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/web-flow/subscriptions',
#    'organizations_url': 'https://api.github.com/users/web-flow/orgs',
#    'repos_url': 'https://api.github.com/users/web-flow/repos',
#    'events_url': 'https://api.github.com/users/web-flow/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/web-flow/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'parents': [{'sha': '9a29398fe629aa62fc5bc237ec20f8461a039f7f',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/commits/9a29398fe629aa62fc5bc237ec20f8461a039f7f',
#     'html_url': 'https://github.com/langchain-ai/langchain/commit/9a29398fe629aa62fc5bc237ec20f8461a039f7f'}]},
#  {'sha': '9a29398fe629aa62fc5bc237ec20f8461a039f7f',
#   'node_id': 'C_kwDOIPDwltoAKDlhMjkzOThmZTYyOWFhNjJmYzViYzIzN2VjMjBmODQ2MWEwMzlmN2Y',
#   'commit': {'author': {'name': 'Mohammad Mohtashim',
#     'email': '45242107+keenborder786@users.noreply.github.com',
#     'date': '2024-08-24T00:45:28Z'},
#    'committer': {'name': 'GitHub',
#     'email': 'noreply@github.com',
#     'date': '2024-08-24T00:45:28Z'},
#    'message': 'huggingface: fix `model` param population (#24743)\n\n- **Description:** Fix the validation error for `endpoint_url` for\r\nHuggingFaceEndpoint. I have given a descriptive detail of the isse in\r\nthe issue that I have created.\r\n- **Issue:** #24742\r\n\r\n---------\r\n\r\nCo-authored-by: Erick Friis <erick@langchain.dev>',
#    'tree': {'sha': 'a91127bc62d87865b07ef666c6767082013c93cb',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/git/trees/a91127bc62d87865b07ef666c6767082013c93cb'},
#    'url': 'https://api.github.com/repos/langchain-ai/langchain/git/commits/9a29398fe629aa62fc5bc237ec20f8461a039f7f',
#    'comment_count': 0,
#    'verification': {'verified': True,
#     'reason': 'valid',
#     'signature': '-----BEGIN PGP SIGNATURE-----\n\\nkg0iyYkh6pmhnBiRYAQ1\n=UT3d\n-----END PGP SIGNATURE-----\n',
#     'payload': 'tree a91127bc62d87865b07ef666c6767082013c93cb\nparent c7a8af2e75e4a762166969ae440bc6f03a9efa42\nauthor Mohammad Mohtashim <45242107+keenborder786@users.noreply.github.com> 1724460328 +0500\ncommitter GitHub <noreply@github.com> 1724460328 +0000\n\nhuggingface: fix `model` param population (#24743)\n\n- **Description:** Fix the validation error for `endpoint_url` for\r\nHuggingFaceEndpoint. I have given a descriptive detail of the isse in\r\nthe issue that I have created.\r\n- **Issue:** #24742\r\n\r\n---------\r\n\r\nCo-authored-by: Erick Friis <erick@langchain.dev>'}},
#   'url': 'https://api.github.com/repos/langchain-ai/langchain/commits/9a29398fe629aa62fc5bc237ec20f8461a039f7f',
#   'html_url': 'https://github.com/langchain-ai/langchain/commit/9a29398fe629aa62fc5bc237ec20f8461a039f7f',
#   'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/commits/9a29398fe629aa62fc5bc237ec20f8461a039f7f/comments',
#   'author': {'login': 'keenborder786',
#    'id': 45242107,
#    'node_id': 'MDQ6VXNlcjQ1MjQyMTA3',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/45242107?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/keenborder786',
#    'html_url': 'https://github.com/keenborder786',
#    'followers_url': 'https://api.github.com/users/keenborder786/followers',
#    'following_url': 'https://api.github.com/users/keenborder786/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/keenborder786/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/keenborder786/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/keenborder786/subscriptions',
#    'organizations_url': 'https://api.github.com/users/keenborder786/orgs',
#    'repos_url': 'https://api.github.com/users/keenborder786/repos',
#    'events_url': 'https://api.github.com/users/keenborder786/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/keenborder786/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'committer': {'login': 'web-flow',
#    'id': 19864447,
#    'node_id': 'MDQ6VXNlcjE5ODY0NDQ3',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/19864447?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/web-flow',
#    'html_url': 'https://github.com/web-flow',
#    'followers_url': 'https://api.github.com/users/web-flow/followers',
#    'following_url': 'https://api.github.com/users/web-flow/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/web-flow/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/web-flow/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/web-flow/subscriptions',
#    'organizations_url': 'https://api.github.com/users/web-flow/orgs',
#    'repos_url': 'https://api.github.com/users/web-flow/repos',
#    'events_url': 'https://api.github.com/users/web-flow/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/web-flow/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'parents': [{'sha': 'c7a8af2e75e4a762166969ae440bc6f03a9efa42',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/commits/c7a8af2e75e4a762166969ae440bc6f03a9efa42',
#     'html_url': 'https://github.com/langchain-ai/langchain/commit/c7a8af2e75e4a762166969ae440bc6f03a9efa42'}]},
#  {'sha': 'c7a8af2e75e4a762166969ae440bc6f03a9efa42',
#   'node_id': 'C_kwDOIPDwltoAKGM3YThhZjJlNzVlNGE3NjIxNjY5NjlhZTQ0MGJjNmYwM2E5ZWZhNDI',
#   'commit': {'author': {'name': 'Yuki Watanabe',
#     'email': '31463517+B-Step62@users.noreply.github.com',
#     'date': '2024-08-24T00:40:21Z'},
#    'committer': {'name': 'GitHub',
#     'email': 'noreply@github.com',
#     'date': '2024-08-24T00:40:21Z'},
#    'message': 'databricks: add vector search and embeddings (#25648)\n\n### Summary\r\n\r\nAdd `DatabricksVectorSearch` and `DatabricksEmbeddings` classes to the\r\n`langchain-databricks` partner packages. Core functionality is\r\nunchanged, but the vector search class is largely refactored for\r\nreadability and maintainability.\r\n\r\nThis PR does not add integration tests yet. This will be added once the\r\nDatabricks test workspace is ready.\r\n\r\nTagging @efriis as POC\r\n\r\n\r\n### Tracker\r\n[✅] Create a package and imgrate ChatDatabricks\r\n[✍️] Migrate DatabricksVectorSearch, DatabricksEmbeddings, and their\r\ndocs\r\n~[ ] Migrate UCFunctionToolkit and its doc~\r\n[ ] Add provider document and update README.md\r\n[ ] Add integration tests and set up secrets (after moved to an external\r\npackage)\r\n[ ] Add deprecation note to the community implementations.\r\n\r\n---------\r\n\r\nSigned-off-by: B-Step62 <yuki.watanabe@databricks.com>\r\nCo-authored-by: Erick Friis <erick@langchain.dev>',
#    'tree': {'sha': '7d672487ed677e3ed0d1c1dde19963cb09eb931d',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/git/trees/7d672487ed677e3ed0d1c1dde19963cb09eb931d'},
#    'url': 'https://api.github.com/repos/langchain-ai/langchain/git/commits/c7a8af2e75e4a762166969ae440bc6f03a9efa42',
#    'comment_count': 0,
#    'verification': {'verified': True,
#     'reason': 'valid',
#     'signature': '-----BEGIN PGP SIGNATURE-----\n\\nbmqkTPq1oMJ5FiulCAZz\n=y1+X\n-----END PGP SIGNATURE-----\n',
#     'payload': 'tree 7d672487ed677e3ed0d1c1dde19963cb09eb931d\nparent 71c039571a88f90ff80af132bff6755ae77f0e2a\nauthor Yuki Watanabe <31463517+B-Step62@users.noreply.github.com> 1724460021 +0900\ncommitter GitHub <noreply@github.com> 1724460021 +0000\n\ndatabricks: add vector search and embeddings (#25648)\n\n### Summary\r\n\r\nAdd `DatabricksVectorSearch` and `DatabricksEmbeddings` classes to the\r\n`langchain-databricks` partner packages. Core functionality is\r\nunchanged, but the vector search class is largely refactored for\r\nreadability and maintainability.\r\n\r\nThis PR does not add integration tests yet. This will be added once the\r\nDatabricks test workspace is ready.\r\n\r\nTagging @efriis as POC\r\n\r\n\r\n### Tracker\r\n[✅] Create a package and imgrate ChatDatabricks\r\n[✍️] Migrate DatabricksVectorSearch, DatabricksEmbeddings, and their\r\ndocs\r\n~[ ] Migrate UCFunctionToolkit and its doc~\r\n[ ] Add provider document and update README.md\r\n[ ] Add integration tests and set up secrets (after moved to an external\r\npackage)\r\n[ ] Add deprecation note to the community implementations.\r\n\r\n---------\r\n\r\nSigned-off-by: B-Step62 <yuki.watanabe@databricks.com>\r\nCo-authored-by: Erick Friis <erick@langchain.dev>'}},
#   'url': 'https://api.github.com/repos/langchain-ai/langchain/commits/c7a8af2e75e4a762166969ae440bc6f03a9efa42',
#   'html_url': 'https://github.com/langchain-ai/langchain/commit/c7a8af2e75e4a762166969ae440bc6f03a9efa42',
#   'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/commits/c7a8af2e75e4a762166969ae440bc6f03a9efa42/comments',
#   'author': {'login': 'B-Step62',
#    'id': 31463517,
#    'node_id': 'MDQ6VXNlcjMxNDYzNTE3',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/31463517?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/B-Step62',
#    'html_url': 'https://github.com/B-Step62',
#    'followers_url': 'https://api.github.com/users/B-Step62/followers',
#    'following_url': 'https://api.github.com/users/B-Step62/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/B-Step62/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/B-Step62/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/B-Step62/subscriptions',
#    'organizations_url': 'https://api.github.com/users/B-Step62/orgs',
#    'repos_url': 'https://api.github.com/users/B-Step62/repos',
#    'events_url': 'https://api.github.com/users/B-Step62/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/B-Step62/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'committer': {'login': 'web-flow',
#    'id': 19864447,
#    'node_id': 'MDQ6VXNlcjE5ODY0NDQ3',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/19864447?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/web-flow',
#    'html_url': 'https://github.com/web-flow',
#    'followers_url': 'https://api.github.com/users/web-flow/followers',
#    'following_url': 'https://api.github.com/users/web-flow/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/web-flow/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/web-flow/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/web-flow/subscriptions',
#    'organizations_url': 'https://api.github.com/users/web-flow/orgs',
#    'repos_url': 'https://api.github.com/users/web-flow/repos',
#    'events_url': 'https://api.github.com/users/web-flow/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/web-flow/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'parents': [{'sha': '71c039571a88f90ff80af132bff6755ae77f0e2a',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/commits/71c039571a88f90ff80af132bff6755ae77f0e2a',
#     'html_url': 'https://github.com/langchain-ai/langchain/commit/71c039571a88f90ff80af132bff6755ae77f0e2a'}]},
#  {'sha': '71c039571a88f90ff80af132bff6755ae77f0e2a',
#   'node_id': 'C_kwDOIPDwltoAKDcxYzAzOTU3MWE4OGY5MGZmODBhZjEzMmJmZjY3NTVhZTc3ZjBlMmE',
#   'commit': {'author': {'name': 'Erick Friis',
#     'email': 'erick@langchain.dev',
#     'date': '2024-08-24T00:36:33Z'},
#    'committer': {'name': 'GitHub',
#     'email': 'noreply@github.com',
#     'date': '2024-08-24T00:36:33Z'},
#    'message': 'docs: remove deprecated nemo embed docs (#25720)',
#    'tree': {'sha': '0cc7e60557ca13ed50d1257dc4f14833424b28e6',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/git/trees/0cc7e60557ca13ed50d1257dc4f14833424b28e6'},
#    'url': 'https://api.github.com/repos/langchain-ai/langchain/git/commits/71c039571a88f90ff80af132bff6755ae77f0e2a',
#    'comment_count': 0,
#    'verification': {'verified': True,
#     'reason': 'valid',
#     'signature': '-----BEGIN PGP SIGNATURE-----\n\\nGjwCHBPOAz4HNZr2iANu\n=ISrh\n-----END PGP SIGNATURE-----\n',
#     'payload': 'tree 0cc7e60557ca13ed50d1257dc4f14833424b28e6\nparent 58e72febeb6cf91f92c05227e50ea8515ee73c94\nauthor Erick Friis <erick@langchain.dev> 1724459793 -0700\ncommitter GitHub <noreply@github.com> 1724459793 +0000\n\ndocs: remove deprecated nemo embed docs (#25720)\n\n'}},
#   'url': 'https://api.github.com/repos/langchain-ai/langchain/commits/71c039571a88f90ff80af132bff6755ae77f0e2a',
#   'html_url': 'https://github.com/langchain-ai/langchain/commit/71c039571a88f90ff80af132bff6755ae77f0e2a',
#   'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/commits/71c039571a88f90ff80af132bff6755ae77f0e2a/comments',
#   'author': {'login': 'efriis',
#    'id': 9557659,
#    'node_id': 'MDQ6VXNlcjk1NTc2NTk=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/9557659?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/efriis',
#    'html_url': 'https://github.com/efriis',
#    'followers_url': 'https://api.github.com/users/efriis/followers',
#    'following_url': 'https://api.github.com/users/efriis/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/efriis/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/efriis/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/efriis/subscriptions',
#    'organizations_url': 'https://api.github.com/users/efriis/orgs',
#    'repos_url': 'https://api.github.com/users/efriis/repos',
#    'events_url': 'https://api.github.com/users/efriis/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/efriis/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'committer': {'login': 'web-flow',
#    'id': 19864447,
#    'node_id': 'MDQ6VXNlcjE5ODY0NDQ3',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/19864447?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/web-flow',
#    'html_url': 'https://github.com/web-flow',
#    'followers_url': 'https://api.github.com/users/web-flow/followers',
#    'following_url': 'https://api.github.com/users/web-flow/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/web-flow/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/web-flow/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/web-flow/subscriptions',
#    'organizations_url': 'https://api.github.com/users/web-flow/orgs',
#    'repos_url': 'https://api.github.com/users/web-flow/repos',
#    'events_url': 'https://api.github.com/users/web-flow/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/web-flow/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'parents': [{'sha': '58e72febeb6cf91f92c05227e50ea8515ee73c94',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/commits/58e72febeb6cf91f92c05227e50ea8515ee73c94',
#     'html_url': 'https://github.com/langchain-ai/langchain/commit/58e72febeb6cf91f92c05227e50ea8515ee73c94'}]},
#  {'sha': '58e72febeb6cf91f92c05227e50ea8515ee73c94',
#   'node_id': 'C_kwDOIPDwltoAKDU4ZTcyZmViZWI2Y2Y5MWY5MmMwNTIyN2U1MGVhODUxNWVlNzNjOTQ',
#   'commit': {'author': {'name': 'Hyman',
#     'email': 'hyman.omg@gmail.com',
#     'date': '2024-08-23T23:59:14Z'},
#    'committer': {'name': 'GitHub',
#     'email': 'noreply@github.com',
#     'date': '2024-08-23T23:59:14Z'},
#    'message': 'openai:compatible with other llm usage meta data (#24500)\n\n- [ ] **PR message**:\r\n- **Description:** Compatible with other llm (eg: deepseek-chat, glm-4)\r\nusage meta data\r\n    - **Issue:** N/A\r\n    - **Dependencies:** no new dependencies added\r\n\r\n\r\n- [ ] **Add tests and docs**: \r\nlibs/partners/openai/tests/unit_tests/chat_models/test_base.py\r\n```shell\r\ncd libs/partners/openai\r\npoetry run pytest tests/unit_tests/chat_models/test_base.py::test_openai_astream\r\npoetry run pytest tests/unit_tests/chat_models/test_base.py::test_openai_stream\r\npoetry run pytest tests/unit_tests/chat_models/test_base.py::test_deepseek_astream\r\npoetry run pytest tests/unit_tests/chat_models/test_base.py::test_deepseek_stream\r\npoetry run pytest tests/unit_tests/chat_models/test_base.py::test_glm4_astream\r\npoetry run pytest tests/unit_tests/chat_models/test_base.py::test_glm4_stream\r\n```\r\n\r\n---------\r\n\r\nCo-authored-by: hyman <hyman@xiaozancloud.com>\r\nCo-authored-by: Erick Friis <erick@langchain.dev>',
#    'tree': {'sha': '79abefeec48213affb8bbc53ea044c1a6b1131d9',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/git/trees/79abefeec48213affb8bbc53ea044c1a6b1131d9'},
#    'url': 'https://api.github.com/repos/langchain-ai/langchain/git/commits/58e72febeb6cf91f92c05227e50ea8515ee73c94',
#    'comment_count': 0,
#    'verification': {'verified': True,
#     'reason': 'valid',
#     'signature': '-----BEGIN PGP SIGNATURE-----\n\\nS4Gt5sWheDwaU31Uzj51\n=F4jx\n-----END PGP SIGNATURE-----\n',
#     'payload': 'tree 79abefeec48213affb8bbc53ea044c1a6b1131d9\nparent 3dc7d447aa53d91c0c26ea336a8690b30b8337df\nauthor Hyman <hyman.omg@gmail.com> 1724457554 +0800\ncommitter GitHub <noreply@github.com> 1724457554 -0700\n\nopenai:compatible with other llm usage meta data (#24500)\n\n- [ ] **PR message**:\r\n- **Description:** Compatible with other llm (eg: deepseek-chat, glm-4)\r\nusage meta data\r\n    - **Issue:** N/A\r\n    - **Dependencies:** no new dependencies added\r\n\r\n\r\n- [ ] **Add tests and docs**: \r\nlibs/partners/openai/tests/unit_tests/chat_models/test_base.py\r\n```shell\r\ncd libs/partners/openai\r\npoetry run pytest tests/unit_tests/chat_models/test_base.py::test_openai_astream\r\npoetry run pytest tests/unit_tests/chat_models/test_base.py::test_openai_stream\r\npoetry run pytest tests/unit_tests/chat_models/test_base.py::test_deepseek_astream\r\npoetry run pytest tests/unit_tests/chat_models/test_base.py::test_deepseek_stream\r\npoetry run pytest tests/unit_tests/chat_models/test_base.py::test_glm4_astream\r\npoetry run pytest tests/unit_tests/chat_models/test_base.py::test_glm4_stream\r\n```\r\n\r\n---------\r\n\r\nCo-authored-by: hyman <hyman@xiaozancloud.com>\r\nCo-authored-by: Erick Friis <erick@langchain.dev>'}},
#   'url': 'https://api.github.com/repos/langchain-ai/langchain/commits/58e72febeb6cf91f92c05227e50ea8515ee73c94',
#   'html_url': 'https://github.com/langchain-ai/langchain/commit/58e72febeb6cf91f92c05227e50ea8515ee73c94',
#   'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/commits/58e72febeb6cf91f92c05227e50ea8515ee73c94/comments',
#   'author': {'login': 'omgbbq',
#    'id': 26438447,
#    'node_id': 'MDQ6VXNlcjI2NDM4NDQ3',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/26438447?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/omgbbq',
#    'html_url': 'https://github.com/omgbbq',
#    'followers_url': 'https://api.github.com/users/omgbbq/followers',
#    'following_url': 'https://api.github.com/users/omgbbq/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/omgbbq/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/omgbbq/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/omgbbq/subscriptions',
#    'organizations_url': 'https://api.github.com/users/omgbbq/orgs',
#    'repos_url': 'https://api.github.com/users/omgbbq/repos',
#    'events_url': 'https://api.github.com/users/omgbbq/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/omgbbq/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'committer': {'login': 'web-flow',
#    'id': 19864447,
#    'node_id': 'MDQ6VXNlcjE5ODY0NDQ3',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/19864447?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/web-flow',
#    'html_url': 'https://github.com/web-flow',
#    'followers_url': 'https://api.github.com/users/web-flow/followers',
#    'following_url': 'https://api.github.com/users/web-flow/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/web-flow/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/web-flow/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/web-flow/subscriptions',
#    'organizations_url': 'https://api.github.com/users/web-flow/orgs',
#    'repos_url': 'https://api.github.com/users/web-flow/repos',
#    'events_url': 'https://api.github.com/users/web-flow/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/web-flow/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'parents': [{'sha': '3dc7d447aa53d91c0c26ea336a8690b30b8337df',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/commits/3dc7d447aa53d91c0c26ea336a8690b30b8337df',
#     'html_url': 'https://github.com/langchain-ai/langchain/commit/3dc7d447aa53d91c0c26ea336a8690b30b8337df'}]},
#  {'sha': '3dc7d447aa53d91c0c26ea336a8690b30b8337df',
#   'node_id': 'C_kwDOIPDwltoAKDNkYzdkNDQ3YWE1M2Q5MWMwYzI2ZWEzMzZhODY5MGIzMGI4MzM3ZGY',
#   'commit': {'author': {'name': 'Erick Friis',
#     'email': 'erick@langchain.dev',
#     'date': '2024-08-23T23:28:42Z'},
#    'committer': {'name': 'GitHub',
#     'email': 'noreply@github.com',
#     'date': '2024-08-23T23:28:42Z'},
#    'message': 'infra: reenable min version testing 2, ci ignore ai21 (#25709)',
#    'tree': {'sha': '84818af20ad106ce448efd332391529031a538a3',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/git/trees/84818af20ad106ce448efd332391529031a538a3'},
#    'url': 'https://api.github.com/repos/langchain-ai/langchain/git/commits/3dc7d447aa53d91c0c26ea336a8690b30b8337df',
#    'comment_count': 0,
#    'verification': {'verified': True,
#     'reason': 'valid',
#     'signature': '-----BEGIN PGP SIGNATURE-----\n\\n+MMSrynKmDU/JmUH2uTo\n=Dt+o\n-----END PGP SIGNATURE-----\n',
#     'payload': 'tree 84818af20ad106ce448efd332391529031a538a3\nparent f6491ceb7d686ae43f3bdf71a09a77e2373a75ec\nauthor Erick Friis <erick@langchain.dev> 1724455722 -0700\ncommitter GitHub <noreply@github.com> 1724455722 +0000\n\ninfra: reenable min version testing 2, ci ignore ai21 (#25709)\n\n'}},
#   'url': 'https://api.github.com/repos/langchain-ai/langchain/commits/3dc7d447aa53d91c0c26ea336a8690b30b8337df',
#   'html_url': 'https://github.com/langchain-ai/langchain/commit/3dc7d447aa53d91c0c26ea336a8690b30b8337df',
#   'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/commits/3dc7d447aa53d91c0c26ea336a8690b30b8337df/comments',
#   'author': {'login': 'efriis',
#    'id': 9557659,
#    'node_id': 'MDQ6VXNlcjk1NTc2NTk=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/9557659?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/efriis',
#    'html_url': 'https://github.com/efriis',
#    'followers_url': 'https://api.github.com/users/efriis/followers',
#    'following_url': 'https://api.github.com/users/efriis/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/efriis/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/efriis/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/efriis/subscriptions',
#    'organizations_url': 'https://api.github.com/users/efriis/orgs',
#    'repos_url': 'https://api.github.com/users/efriis/repos',
#    'events_url': 'https://api.github.com/users/efriis/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/efriis/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'committer': {'login': 'web-flow',
#    'id': 19864447,
#    'node_id': 'MDQ6VXNlcjE5ODY0NDQ3',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/19864447?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/web-flow',
#    'html_url': 'https://github.com/web-flow',
#    'followers_url': 'https://api.github.com/users/web-flow/followers',
#    'following_url': 'https://api.github.com/users/web-flow/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/web-flow/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/web-flow/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/web-flow/subscriptions',
#    'organizations_url': 'https://api.github.com/users/web-flow/orgs',
#    'repos_url': 'https://api.github.com/users/web-flow/repos',
#    'events_url': 'https://api.github.com/users/web-flow/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/web-flow/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'parents': [{'sha': 'f6491ceb7d686ae43f3bdf71a09a77e2373a75ec',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/commits/f6491ceb7d686ae43f3bdf71a09a77e2373a75ec',
#     'html_url': 'https://github.com/langchain-ai/langchain/commit/f6491ceb7d686ae43f3bdf71a09a77e2373a75ec'}]},
#  {'sha': 'f6491ceb7d686ae43f3bdf71a09a77e2373a75ec',
#   'node_id': 'C_kwDOIPDwltoAKGY2NDkxY2ViN2Q2ODZhZTQzZjNiZGY3MWEwOWE3N2UyMzczYTc1ZWM',
#   'commit': {'author': {'name': 'Erick Friis',
#     'email': 'erick@langchain.dev',
#     'date': '2024-08-23T23:25:17Z'},
#    'committer': {'name': 'GitHub',
#     'email': 'noreply@github.com',
#     'date': '2024-08-23T23:25:17Z'},
#    'message': 'community: remove integration test deps (#24460)\n\nthey arent used',
#    'tree': {'sha': 'adf71eb029f43f1848df19b01095a35b30642a5b',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/git/trees/adf71eb029f43f1848df19b01095a35b30642a5b'},
#    'url': 'https://api.github.com/repos/langchain-ai/langchain/git/commits/f6491ceb7d686ae43f3bdf71a09a77e2373a75ec',
#    'comment_count': 0,
#    'verification': {'verified': True,
#     'reason': 'valid',
#     'signature': '-----BEGIN PGP SIGNATURE-----\n\\naPqChw26qVZTptSrNvpf\n=FJ2n\n-----END PGP SIGNATURE-----\n',
#     'payload': 'tree adf71eb029f43f1848df19b01095a35b30642a5b\nparent 0022ae1b3130edf559f13b4702e929502f501ecd\nauthor Erick Friis <erick@langchain.dev> 1724455517 -0700\ncommitter GitHub <noreply@github.com> 1724455517 +0000\n\ncommunity: remove integration test deps (#24460)\n\nthey arent used'}},
#   'url': 'https://api.github.com/repos/langchain-ai/langchain/commits/f6491ceb7d686ae43f3bdf71a09a77e2373a75ec',
#   'html_url': 'https://github.com/langchain-ai/langchain/commit/f6491ceb7d686ae43f3bdf71a09a77e2373a75ec',
#   'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/commits/f6491ceb7d686ae43f3bdf71a09a77e2373a75ec/comments',
#   'author': {'login': 'efriis',
#    'id': 9557659,
#    'node_id': 'MDQ6VXNlcjk1NTc2NTk=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/9557659?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/efriis',
#    'html_url': 'https://github.com/efriis',
#    'followers_url': 'https://api.github.com/users/efriis/followers',
#    'following_url': 'https://api.github.com/users/efriis/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/efriis/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/efriis/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/efriis/subscriptions',
#    'organizations_url': 'https://api.github.com/users/efriis/orgs',
#    'repos_url': 'https://api.github.com/users/efriis/repos',
#    'events_url': 'https://api.github.com/users/efriis/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/efriis/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'committer': {'login': 'web-flow',
#    'id': 19864447,
#    'node_id': 'MDQ6VXNlcjE5ODY0NDQ3',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/19864447?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/web-flow',
#    'html_url': 'https://github.com/web-flow',
#    'followers_url': 'https://api.github.com/users/web-flow/followers',
#    'following_url': 'https://api.github.com/users/web-flow/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/web-flow/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/web-flow/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/web-flow/subscriptions',
#    'organizations_url': 'https://api.github.com/users/web-flow/orgs',
#    'repos_url': 'https://api.github.com/users/web-flow/repos',
#    'events_url': 'https://api.github.com/users/web-flow/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/web-flow/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'parents': [{'sha': '0022ae1b3130edf559f13b4702e929502f501ecd',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/commits/0022ae1b3130edf559f13b4702e929502f501ecd',
#     'html_url': 'https://github.com/langchain-ai/langchain/commit/0022ae1b3130edf559f13b4702e929502f501ecd'}]},
#  {'sha': '0022ae1b3130edf559f13b4702e929502f501ecd',
#   'node_id': 'C_kwDOIPDwltoAKDAwMjJhZTFiMzEzMGVkZjU1OWYxM2I0NzAyZTkyOTUwMmY1MDFlY2Q',
#   'commit': {'author': {'name': 'Erick Friis',
#     'email': 'erick@langchain.dev',
#     'date': '2024-08-23T22:51:12Z'},
#    'committer': {'name': 'GitHub',
#     'email': 'noreply@github.com',
#     'date': '2024-08-23T22:51:12Z'},
#    'message': 'docs: remove templates (#25717)\n\n- [x] check redirect works at template root\r\n- [x] check redirect works within individual template page',
#    'tree': {'sha': '53309e97491701cc609f6b80c040152f6b50e473',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/git/trees/53309e97491701cc609f6b80c040152f6b50e473'},
#    'url': 'https://api.github.com/repos/langchain-ai/langchain/git/commits/0022ae1b3130edf559f13b4702e929502f501ecd',
#    'comment_count': 0,
#    'verification': {'verified': True,
#     'reason': 'valid',
#     'signature': '-----BEGIN PGP SIGNATURE-----\n\\nc/ip1U2oCqQ/xEI8rVGv\n=N+/A\n-----END PGP SIGNATURE-----\n',
#     'payload': 'tree 53309e97491701cc609f6b80c040152f6b50e473\nparent 90439b12f65660536afd0388863a87fadd8396cf\nauthor Erick Friis <erick@langchain.dev> 1724453472 -0700\ncommitter GitHub <noreply@github.com> 1724453472 -0700\n\ndocs: remove templates (#25717)\n\n- [x] check redirect works at template root\r\n- [x] check redirect works within individual template page'}},
#   'url': 'https://api.github.com/repos/langchain-ai/langchain/commits/0022ae1b3130edf559f13b4702e929502f501ecd',
#   'html_url': 'https://github.com/langchain-ai/langchain/commit/0022ae1b3130edf559f13b4702e929502f501ecd',
#   'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/commits/0022ae1b3130edf559f13b4702e929502f501ecd/comments',
#   'author': {'login': 'efriis',
#    'id': 9557659,
#    'node_id': 'MDQ6VXNlcjk1NTc2NTk=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/9557659?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/efriis',
#    'html_url': 'https://github.com/efriis',
#    'followers_url': 'https://api.github.com/users/efriis/followers',
#    'following_url': 'https://api.github.com/users/efriis/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/efriis/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/efriis/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/efriis/subscriptions',
#    'organizations_url': 'https://api.github.com/users/efriis/orgs',
#    'repos_url': 'https://api.github.com/users/efriis/repos',
#    'events_url': 'https://api.github.com/users/efriis/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/efriis/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'committer': {'login': 'web-flow',
#    'id': 19864447,
#    'node_id': 'MDQ6VXNlcjE5ODY0NDQ3',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/19864447?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/web-flow',
#    'html_url': 'https://github.com/web-flow',
#    'followers_url': 'https://api.github.com/users/web-flow/followers',
#    'following_url': 'https://api.github.com/users/web-flow/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/web-flow/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/web-flow/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/web-flow/subscriptions',
#    'organizations_url': 'https://api.github.com/users/web-flow/orgs',
#    'repos_url': 'https://api.github.com/users/web-flow/repos',
#    'events_url': 'https://api.github.com/users/web-flow/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/web-flow/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'parents': [{'sha': '90439b12f65660536afd0388863a87fadd8396cf',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/commits/90439b12f65660536afd0388863a87fadd8396cf',
#     'html_url': 'https://github.com/langchain-ai/langchain/commit/90439b12f65660536afd0388863a87fadd8396cf'}]},
#  {'sha': '90439b12f65660536afd0388863a87fadd8396cf',
#   'node_id': 'C_kwDOIPDwltoAKDkwNDM5YjEyZjY1NjYwNTM2YWZkMDM4ODg2M2E4N2ZhZGQ4Mzk2Y2Y',
#   'commit': {'author': {'name': 'Sharmistha S. Gupta',
#     'email': 'ssgupta@umass.edu',
#     'date': '2024-08-23T22:34:32Z'},
#    'committer': {'name': 'GitHub',
#     'email': 'noreply@github.com',
#     'date': '2024-08-23T22:34:32Z'},
#    'message': 'Added support for Nebula Chat model (#21925)\n\nDescription: Added support for Nebula Chat model in addition to Nebula\r\nInstruct\r\nDependencies: N/A\r\nTwitter handle: @Symbldotai\r\n\r\n---------\r\n\r\nCo-authored-by: Eugene Yurtsev <eugene@langchain.dev>\r\nCo-authored-by: Bagatur <22008038+baskaryan@users.noreply.github.com>\r\nCo-authored-by: Bagatur <baskaryan@gmail.com>\r\nCo-authored-by: Chester Curme <chester.curme@gmail.com>',
#    'tree': {'sha': 'c857e70c5f6f2c73bf2ab9a72bba021776e1c99a',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/git/trees/c857e70c5f6f2c73bf2ab9a72bba021776e1c99a'},
#    'url': 'https://api.github.com/repos/langchain-ai/langchain/git/commits/90439b12f65660536afd0388863a87fadd8396cf',
#    'comment_count': 0,
#    'verification': {'verified': True,
#     'reason': 'valid',
#     'signature': '-----BEGIN PGP SIGNATURE-----\n\\nrbpzVn/BOcn8SNfufcyE\n=EywW\n-----END PGP SIGNATURE-----\n',
#     'payload': 'tree c857e70c5f6f2c73bf2ab9a72bba021776e1c99a\nparent 080741d336cc1e190db7ed3fceb3887dee7af7ec\nauthor Sharmistha S. Gupta <ssgupta@umass.edu> 1724452472 -0700\ncommitter GitHub <noreply@github.com> 1724452472 +0000\n\nAdded support for Nebula Chat model (#21925)\n\nDescription: Added support for Nebula Chat model in addition to Nebula\r\nInstruct\r\nDependencies: N/A\r\nTwitter handle: @Symbldotai\r\n\r\n---------\r\n\r\nCo-authored-by: Eugene Yurtsev <eugene@langchain.dev>\r\nCo-authored-by: Bagatur <22008038+baskaryan@users.noreply.github.com>\r\nCo-authored-by: Bagatur <baskaryan@gmail.com>\r\nCo-authored-by: Chester Curme <chester.curme@gmail.com>'}},
#   'url': 'https://api.github.com/repos/langchain-ai/langchain/commits/90439b12f65660536afd0388863a87fadd8396cf',
#   'html_url': 'https://github.com/langchain-ai/langchain/commit/90439b12f65660536afd0388863a87fadd8396cf',
#   'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/commits/90439b12f65660536afd0388863a87fadd8396cf/comments',
#   'author': {'login': 'sharmisthasg',
#    'id': 29104739,
#    'node_id': 'MDQ6VXNlcjI5MTA0NzM5',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/29104739?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/sharmisthasg',
#    'html_url': 'https://github.com/sharmisthasg',
#    'followers_url': 'https://api.github.com/users/sharmisthasg/followers',
#    'following_url': 'https://api.github.com/users/sharmisthasg/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/sharmisthasg/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/sharmisthasg/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/sharmisthasg/subscriptions',
#    'organizations_url': 'https://api.github.com/users/sharmisthasg/orgs',
#    'repos_url': 'https://api.github.com/users/sharmisthasg/repos',
#    'events_url': 'https://api.github.com/users/sharmisthasg/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/sharmisthasg/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'committer': {'login': 'web-flow',
#    'id': 19864447,
#    'node_id': 'MDQ6VXNlcjE5ODY0NDQ3',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/19864447?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/web-flow',
#    'html_url': 'https://github.com/web-flow',
#    'followers_url': 'https://api.github.com/users/web-flow/followers',
#    'following_url': 'https://api.github.com/users/web-flow/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/web-flow/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/web-flow/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/web-flow/subscriptions',
#    'organizations_url': 'https://api.github.com/users/web-flow/orgs',
#    'repos_url': 'https://api.github.com/users/web-flow/repos',
#    'events_url': 'https://api.github.com/users/web-flow/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/web-flow/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'parents': [{'sha': '080741d336cc1e190db7ed3fceb3887dee7af7ec',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/commits/080741d336cc1e190db7ed3fceb3887dee7af7ec',
#     'html_url': 'https://github.com/langchain-ai/langchain/commit/080741d336cc1e190db7ed3fceb3887dee7af7ec'}]},
#  {'sha': '080741d336cc1e190db7ed3fceb3887dee7af7ec',
#   'node_id': 'C_kwDOIPDwltoAKDA4MDc0MWQzMzZjYzFlMTkwZGI3ZWQzZmNlYjM4ODdkZWU3YWY3ZWM',
#   'commit': {'author': {'name': 'James Espichan Vilca',
#     'email': '84110446+jamesev15@users.noreply.github.com',
#     'date': '2024-08-23T21:06:39Z'},
#    'committer': {'name': 'GitHub',
#     'email': 'noreply@github.com',
#     'date': '2024-08-23T21:06:39Z'},
# ...
#     'payload': 'tree bde7b11357c3b912910f26d66b2f344e81b6daef\nparent 3c7f12cbf55a641998bdaab4a8959cef8eb90d30\nauthor conjuncts <67614673+conjuncts@users.noreply.github.com> 1724422257 -0500\ncommitter GitHub <noreply@github.com> 1724422257 -0400\n\ncommunity: allow chroma DB delete() to use "where" argument (#19826)\n\nThank you for contributing to LangChain!\r\n\r\n- [x] **PR title**: "package: description"\r\n- Where "package" is whichever of langchain, community, core,\r\nexperimental, etc. is being modified. Use "docs: ..." for purely docs\r\nchanges, "templates: ..." for template changes, "infra: ..." for CI\r\nchanges.\r\n  - Example: "community: add foobar LLM"\r\n\r\nDescription: Simply pass kwargs to allow arguments like "where" to be\r\npropagated\r\nIssue: Previously, db.delete(where={}) wouldn\'t work for chroma\r\nvectorstores\r\nDependencies: N/A\r\nTwitter handle: N/A\r\n\r\n- [x] **Add tests and docs**: If you\'re adding a new integration, please\r\ninclude\r\n1. a test for the integration, preferably unit tests that do not rely on\r\nnetwork access,\r\n2. an example notebook showing its use. It lives in\r\n`docs/docs/integrations` directory.\r\n\r\n\r\n- [x] **Lint and test**: Run `make format`, `make lint` and `make test`\r\nfrom the root of the package(s) you\'ve modified. See contribution\r\nguidelines for more: https://python.langchain.com/docs/contributing/\r\n\r\nAdditional guidelines:\r\n- Make sure optional dependencies are imported within a function.\r\n- Please do not add dependencies to pyproject.toml files (even optional\r\nones) unless they are required for unit tests.\r\n- Most PRs should not touch more than one package.\r\n- Changes should be backwards compatible.\r\n- If you are adding something to community, do not re-import it in\r\nlangchain.\r\n\r\nIf no one reviews your PR within a few days, please @-mention one of\r\nbaskaryan, efriis, eyurtsev, hwchase17.'}},
#   'url': 'https://api.github.com/repos/langchain-ai/langchain/commits/818267bbc349afac522204c4ba62b9e388a0259f',
#   'html_url': 'https://github.com/langchain-ai/langchain/commit/818267bbc349afac522204c4ba62b9e388a0259f',
#   'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/commits/818267bbc349afac522204c4ba62b9e388a0259f/comments',
#   'author': {'login': 'conjuncts',
#    'id': 67614673,
#    'node_id': 'MDQ6VXNlcjY3NjE0Njcz',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/67614673?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/conjuncts',
#    'html_url': 'https://github.com/conjuncts',
#    'followers_url': 'https://api.github.com/users/conjuncts/followers',
#    'following_url': 'https://api.github.com/users/conjuncts/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/conjuncts/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/conjuncts/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/conjuncts/subscriptions',
#    'organizations_url': 'https://api.github.com/users/conjuncts/orgs',
#    'repos_url': 'https://api.github.com/users/conjuncts/repos',
#    'events_url': 'https://api.github.com/users/conjuncts/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/conjuncts/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'committer': {'login': 'web-flow',
#    'id': 19864447,
#    'node_id': 'MDQ6VXNlcjE5ODY0NDQ3',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/19864447?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/web-flow',
#    'html_url': 'https://github.com/web-flow',
#    'followers_url': 'https://api.github.com/users/web-flow/followers',
#    'following_url': 'https://api.github.com/users/web-flow/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/web-flow/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/web-flow/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/web-flow/subscriptions',
#    'organizations_url': 'https://api.github.com/users/web-flow/orgs',
#    'repos_url': 'https://api.github.com/users/web-flow/repos',
#    'events_url': 'https://api.github.com/users/web-flow/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/web-flow/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'parents': [{'sha': '3c7f12cbf55a641998bdaab4a8959cef8eb90d30',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/commits/3c7f12cbf55a641998bdaab4a8959cef8eb90d30',
#     'html_url': 'https://github.com/langchain-ai/langchain/commit/3c7f12cbf55a641998bdaab4a8959cef8eb90d30'}]},
#  {'sha': '3c7f12cbf55a641998bdaab4a8959cef8eb90d30',
#   'node_id': 'C_kwDOIPDwltoAKDNjN2YxMmNiZjU1YTY0MTk5OGJkYWFiNGE4OTU5Y2VmOGViOTBkMzA',
#   'commit': {'author': {'name': 'Kevin Engelke',
#     'email': '34512569+KevinHubert-Dev@users.noreply.github.com',
#     'date': '2024-08-23T12:59:38Z'},
#    'committer': {'name': 'GitHub',
#     'email': 'noreply@github.com',
#     'date': '2024-08-23T12:59:38Z'},
#    'message': "community[minor]: Fix missing 'keep_newlines' parameter forward-pass to 'process_pages' function in confluence loader (#20086) (#20087)\n\n- **Description:** Fixed missing `keep_newlines` parameter forward-pass\r\nin confluence-loader\r\n- **Issue:** #20086 \r\n- **Dependencies:** None\r\n\r\n---------\r\n\r\nCo-authored-by: ccurme <chester.curme@gmail.com>",
#    'tree': {'sha': '9613b77f59e04b193b8ac7eecbb1b9cbf28afc20',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/git/trees/9613b77f59e04b193b8ac7eecbb1b9cbf28afc20'},
#    'url': 'https://api.github.com/repos/langchain-ai/langchain/git/commits/3c7f12cbf55a641998bdaab4a8959cef8eb90d30',
#    'comment_count': 0,
#    'verification': {'verified': True,
#     'reason': 'valid',
#     'signature': '-----BEGIN PGP SIGNATURE-----\n\\nTgkRSfgYntXCinmeR6EM\n=qL3C\n-----END PGP SIGNATURE-----\n',
#     'payload': "tree 9613b77f59e04b193b8ac7eecbb1b9cbf28afc20\nparent 583b0449ebcfa94f9cc2340537d668e62c5c56de\nauthor Kevin Engelke <34512569+KevinHubert-Dev@users.noreply.github.com> 1724417978 +0200\ncommitter GitHub <noreply@github.com> 1724417978 +0000\n\ncommunity[minor]: Fix missing 'keep_newlines' parameter forward-pass to 'process_pages' function in confluence loader (#20086) (#20087)\n\n- **Description:** Fixed missing `keep_newlines` parameter forward-pass\r\nin confluence-loader\r\n- **Issue:** #20086 \r\n- **Dependencies:** None\r\n\r\n---------\r\n\r\nCo-authored-by: ccurme <chester.curme@gmail.com>"}},
#   'url': 'https://api.github.com/repos/langchain-ai/langchain/commits/3c7f12cbf55a641998bdaab4a8959cef8eb90d30',
#   'html_url': 'https://github.com/langchain-ai/langchain/commit/3c7f12cbf55a641998bdaab4a8959cef8eb90d30',
#   'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/commits/3c7f12cbf55a641998bdaab4a8959cef8eb90d30/comments',
#   'author': {'login': 'KevinHubert-Dev',
#    'id': 34512569,
#    'node_id': 'MDQ6VXNlcjM0NTEyNTY5',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/34512569?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/KevinHubert-Dev',
#    'html_url': 'https://github.com/KevinHubert-Dev',
#    'followers_url': 'https://api.github.com/users/KevinHubert-Dev/followers',
#    'following_url': 'https://api.github.com/users/KevinHubert-Dev/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/KevinHubert-Dev/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/KevinHubert-Dev/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/KevinHubert-Dev/subscriptions',
#    'organizations_url': 'https://api.github.com/users/KevinHubert-Dev/orgs',
#    'repos_url': 'https://api.github.com/users/KevinHubert-Dev/repos',
#    'events_url': 'https://api.github.com/users/KevinHubert-Dev/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/KevinHubert-Dev/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'committer': {'login': 'web-flow',
#    'id': 19864447,
#    'node_id': 'MDQ6VXNlcjE5ODY0NDQ3',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/19864447?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/web-flow',
#    'html_url': 'https://github.com/web-flow',
#    'followers_url': 'https://api.github.com/users/web-flow/followers',
#    'following_url': 'https://api.github.com/users/web-flow/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/web-flow/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/web-flow/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/web-flow/subscriptions',
#    'organizations_url': 'https://api.github.com/users/web-flow/orgs',
#    'repos_url': 'https://api.github.com/users/web-flow/repos',
#    'events_url': 'https://api.github.com/users/web-flow/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/web-flow/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'parents': [{'sha': '583b0449ebcfa94f9cc2340537d668e62c5c56de',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/commits/583b0449ebcfa94f9cc2340537d668e62c5c56de',
#     'html_url': 'https://github.com/langchain-ai/langchain/commit/583b0449ebcfa94f9cc2340537d668e62c5c56de'}]},
#  {'sha': '583b0449ebcfa94f9cc2340537d668e62c5c56de',
#   'node_id': 'C_kwDOIPDwltoAKDU4M2IwNDQ5ZWJjZmE5NGY5Y2MyMzQwNTM3ZDY2OGU2MmM1YzU2ZGU',
#   'commit': {'author': {'name': 'Erik Lindgren',
#     'email': '149605443+erikml-db@users.noreply.github.com',
#     'date': '2024-08-23T08:57:13Z'},
#    'committer': {'name': 'GitHub',
#     'email': 'noreply@github.com',
#     'date': '2024-08-23T08:57:13Z'},
#    'message': "community[patch]: Fix Hybrid Search for non-Databricks managed embeddings (#25590)\n\nDescription: Send both the query and query_embedding to the Databricks\r\nindex for hybrid search.\r\n\r\nIssue: When using hybrid search with non-Databricks managed embedding we\r\ncurrently don't pass both the embedding and query_text to the index.\r\nHybrid search requires both of these. This change fixes this issue for\r\nboth `similarity_search` and `similarity_search_by_vector`.\r\n\r\n---------\r\n\r\nCo-authored-by: Erick Friis <erick@langchain.dev>",
#    'tree': {'sha': '4f903480db48a1673d6429be7e11f6d75dcb0e2a',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/git/trees/4f903480db48a1673d6429be7e11f6d75dcb0e2a'},
#    'url': 'https://api.github.com/repos/langchain-ai/langchain/git/commits/583b0449ebcfa94f9cc2340537d668e62c5c56de',
#    'comment_count': 0,
#    'verification': {'verified': True,
#     'reason': 'valid',
#     'signature': '-----BEGIN PGP SIGNATURE-----\n\\n1Dz9xT51F917zJH8zSET\n=6Y5K\n-----END PGP SIGNATURE-----\n',
#     'payload': "tree 4f903480db48a1673d6429be7e11f6d75dcb0e2a\nparent bcd5842b5d7f559a81d3cc5d4d486c84cc3ab8da\nauthor Erik Lindgren <149605443+erikml-db@users.noreply.github.com> 1724403433 -0400\ncommitter GitHub <noreply@github.com> 1724403433 +0000\n\ncommunity[patch]: Fix Hybrid Search for non-Databricks managed embeddings (#25590)\n\nDescription: Send both the query and query_embedding to the Databricks\r\nindex for hybrid search.\r\n\r\nIssue: When using hybrid search with non-Databricks managed embedding we\r\ncurrently don't pass both the embedding and query_text to the index.\r\nHybrid search requires both of these. This change fixes this issue for\r\nboth `similarity_search` and `similarity_search_by_vector`.\r\n\r\n---------\r\n\r\nCo-authored-by: Erick Friis <erick@langchain.dev>"}},
#   'url': 'https://api.github.com/repos/langchain-ai/langchain/commits/583b0449ebcfa94f9cc2340537d668e62c5c56de',
#   'html_url': 'https://github.com/langchain-ai/langchain/commit/583b0449ebcfa94f9cc2340537d668e62c5c56de',
#   'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/commits/583b0449ebcfa94f9cc2340537d668e62c5c56de/comments',
#   'author': {'login': 'erikml-db',
#    'id': 149605443,
#    'node_id': 'U_kgDOCOrMQw',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/149605443?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/erikml-db',
#    'html_url': 'https://github.com/erikml-db',
#    'followers_url': 'https://api.github.com/users/erikml-db/followers',
#    'following_url': 'https://api.github.com/users/erikml-db/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/erikml-db/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/erikml-db/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/erikml-db/subscriptions',
#    'organizations_url': 'https://api.github.com/users/erikml-db/orgs',
#    'repos_url': 'https://api.github.com/users/erikml-db/repos',
#    'events_url': 'https://api.github.com/users/erikml-db/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/erikml-db/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'committer': {'login': 'web-flow',
#    'id': 19864447,
#    'node_id': 'MDQ6VXNlcjE5ODY0NDQ3',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/19864447?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/web-flow',
#    'html_url': 'https://github.com/web-flow',
#    'followers_url': 'https://api.github.com/users/web-flow/followers',
#    'following_url': 'https://api.github.com/users/web-flow/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/web-flow/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/web-flow/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/web-flow/subscriptions',
#    'organizations_url': 'https://api.github.com/users/web-flow/orgs',
#    'repos_url': 'https://api.github.com/users/web-flow/repos',
#    'events_url': 'https://api.github.com/users/web-flow/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/web-flow/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'parents': [{'sha': 'bcd5842b5d7f559a81d3cc5d4d486c84cc3ab8da',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/commits/bcd5842b5d7f559a81d3cc5d4d486c84cc3ab8da',
#     'html_url': 'https://github.com/langchain-ai/langchain/commit/bcd5842b5d7f559a81d3cc5d4d486c84cc3ab8da'}]}]

# %% [markdown]
# ## 解析导出每日进展
#
# API 请求返回结构过于复杂，我们先解析 `title` 字段，即仅查看和总结 GitHub 项目 Issues list 和 PRs List 标题。如下所示：
#
# ![Issues](images/issues.png)
#
# https://github.com/langchain-ai/langchain/issues

# %%
github_client.export_daily_progress(repo)
# Out:
# Exported daily progress to langchain-ai_langchain_2024-08-25.md
# 'langchain-ai_langchain_2024-08-25.md'

# %% [markdown]
# ### 查看文档 发现问题并不简单😈😈
#
# #### Note: Every pull request is an issue
#
# > GitHub's REST API considers every pull request an issue, but not every issue is a pull request. For this reason, "Issues" endpoints may return both issues and pull requests in the response. You can identify pull requests by the pull_request key. Be aware that the id of a pull request returned from "Issues" endpoints will be an issue id. To find out the pull request id, use the "List pull requests" endpoint.

# %% [markdown]
# # 支持条件筛选的 GitHub 项目进展获取
#
# 实际开发场景中，项目进展通常不是刚好以天为周期时。因此，这便暴露出v0.2版本的 `GitHubClient` 在信息获取方面的局限性。
#
#
# 下面我们扩展 v0.2 版本的 `GitHubClient`，使其支持根据筛选条件获取 GitHub 项目的 Issues 和 Pull Requests。首要支持的筛选条便是**研发周期（时间段）**，**已合并的PR** 和 **已关闭的Issues**：
#
# ![langchain_week_progress](images/langchain_week_progress.jpg)
#
# 通过阅读 GitHub API 文档（https://docs.github.com/en/rest/issues/issues?apiVersion=2022-11-28#list-repository-issues--code-samples ），我们便能了解最关键的2个字段是：
#
# - state(string): Indicates the state of the issues to return.
#     - Default: open
#     - Can be one of: open, closed, all
# - since(string): Only show results that were last updated after the given time. This is a timestamp in ISO 8601 format: YYYY-MM-DDTHH:MM:SSZ.
#
# 从功能完整性角度，我们还可以增加一个 `until` 条件，以支持研发周期的结束时间筛选。😈😈
#
#
# 下面以 Langchain 项目 (https://github.com/langchain-ai/langchain) 为例，展示如何使用扩展后的 GitHubClient
#
# ## [v0.3] GitHubClient Class

# %%
# src/logger.py
from loguru import logger
import sys

# Configure Loguru
logger.remove()  # Remove the default logger
logger.add(sys.stdout, level="DEBUG", format="{time} {level} {message}", colorize=True)
logger.add("logs/app.log", rotation="1 MB", level="DEBUG")

# Alias the logger for easier import
LOG = logger

# Make the logger available for import with the alias
__all__ = ["LOG"]


# src/github_client.py

import requests  # 导入requests库用于HTTP请求
from datetime import datetime, date, timedelta  # 导入日期处理模块
import os  # 导入os模块用于文件和目录操作
# from logger import LOG  # 导入日志模块（演示时直接导入）

class GitHubClient:
    def __init__(self, token):
        self.token = token  # GitHub API令牌
        self.headers = {'Authorization': f'token {self.token}'}  # 设置HTTP头部认证信息

    def fetch_updates(self, repo, since=None, until=None):
        # 获取指定仓库的更新，可以指定开始和结束日期
        updates = {
            'commits': self.fetch_commits(repo, since, until),  # 获取提交记录
            'issues': self.fetch_issues(repo, since, until),  # 获取问题
            'pull_requests': self.fetch_pull_requests(repo, since, until)  # 获取拉取请求
        }
        return updates

    def fetch_commits(self, repo, since=None, until=None):
        url = f'https://api.github.com/repos/{repo}/commits'  # 构建获取提交的API URL
        params = {}
        if since:
            params['since'] = since  # 如果指定了开始日期，添加到参数中
        if until:
            params['until'] = until  # 如果指定了结束日期，添加到参数中

        response = requests.get(url, headers=self.headers, params=params)
        response.raise_for_status()  # 检查请求是否成功
        return response.json()  # 返回JSON格式的数据

    def fetch_issues(self, repo, since=None, until=None):
        url = f'https://api.github.com/repos/{repo}/issues'  # 构建获取问题的API URL
        params = {
            'state': 'closed',  # 仅获取已关闭的问题
            'since': since,
            'until': until
        }
        response = requests.get(url, headers=self.headers, params=params)
        response.raise_for_status()
        return response.json()

    def fetch_pull_requests(self, repo, since=None, until=None):
        url = f'https://api.github.com/repos/{repo}/pulls'  # 构建获取拉取请求的API URL
        params = {
            'state': 'closed',  # 仅获取已合并的拉取请求
            'since': since,
            'until': until
        }
        response = requests.get(url, headers=self.headers, params=params)
        response.raise_for_status()
        return response.json()

    def export_daily_progress(self, repo):
        today = datetime.now().date().isoformat()  # 获取今天的日期
        updates = self.fetch_updates(repo, since=today)  # 获取今天的更新数据
        
        repo_dir = os.path.join('daily_progress', repo.replace("/", "_"))  # 构建存储路径
        os.makedirs(repo_dir, exist_ok=True)  # 确保目录存在
        
        file_path = os.path.join(repo_dir, f'{today}.md')  # 构建文件路径
        with open(file_path, 'w') as file:
            file.write(f"# Daily Progress for {repo} ({today})\n\n")
            file.write("\n## Issues Closed Today\n")
            for issue in updates['issues']:  # 写入今天关闭的问题
                file.write(f"- {issue['title']} #{issue['number']}\n")
            file.write("\n## Pull Requests Merged Today\n")
            for pr in updates['pull_requests']:  # 写入今天合并的拉取请求
                file.write(f"- {pr['title']} #{pr['number']}\n")
        
        LOG.info(f"Exported daily progress to {file_path}")  # 记录日志
        return file_path

    def export_progress_by_date_range(self, repo, days):
        today = date.today()  # 获取当前日期
        since = today - timedelta(days=days)  # 计算开始日期
        
        updates = self.fetch_updates(repo, since=since.isoformat(), until=today.isoformat())  # 获取指定日期范围内的更新
        
        repo_dir = os.path.join('daily_progress', repo.replace("/", "_"))  # 构建目录路径
        os.makedirs(repo_dir, exist_ok=True)  # 确保目录存在
        
        # 更新文件名以包含日期范围
        date_str = f"{since}_to_{today}"
        file_path = os.path.join(repo_dir, f'{date_str}.md')  # 构建文件路径
        
        with open(file_path, 'w') as file:
            file.write(f"# Progress for {repo} ({since} to {today})\n\n")
            file.write(f"\n## Issues Closed in the Last {days} Days\n")
            for issue in updates['issues']:  # 写入在指定日期内关闭的问题
                file.write(f"- {issue['title']} #{issue['number']}\n")
            file.write(f"\n## Pull Requests Merged in the Last {days} Days\n")
            for pr in updates['pull_requests']:  # 写入在指定日期内合并的拉取请求
                file.write(f"- {pr['title']} #{pr['number']}\n")
        
        LOG.info(f"Exported time-range progress to {file_path}")  # 记录日志
        return file_path

# %%
# 实例化 v0.3 版本的 GitHub Client
github_client = GitHubClient(token=os.getenv("GITHUB_TOKEN"))

# %% [markdown]
# ### 获取过去1天 LangChain 进展（已关闭的Issues）

# %%
#import datetime

# 获取今天的日期，从午夜开始，ISO 8601格式
today = datetime.now().replace(hour=0, minute=0, second=0, microsecond=0).isoformat()

# 获取今天关闭的Issues
closed_issues_today = github_client.fetch_issues(repo='langchain-ai/langchain', since=today, until=today)

# 打印今天关闭的Issues标题
for issue in closed_issues_today:
    print(f"Issue #{issue['number']}: {issue['title']} (关闭时间 {issue['closed_at']})")

# %%
# 获取过去3天的日期
three_days_ago = datetime.now() - timedelta(days=3)
three_days_ago = three_days_ago.replace(hour=0, minute=0, second=0, microsecond=0).isoformat()

# 获取过去3天关闭的Issues
closed_issues_last_3_days = github_client.fetch_issues(repo='langchain-ai/langchain', since=three_days_ago, until=today)

# 打印过去3天关闭的Issues标题
for issue in closed_issues_last_3_days:
    print(f"Issue #{issue['number']}: {issue['title']} (关闭时间 {issue['closed_at']})")
# Out:
# Issue #25720: docs: remove deprecated nemo embed docs (关闭时间 2024-08-24T00:36:33Z)
# Issue #25717: docs: remove templates (关闭时间 2024-08-23T22:51:12Z)
# Issue #25715: infra: continue on error (关闭时间 2024-08-23T22:58:09Z)
# Issue #25713: Fix type for inner input in base prompts (关闭时间 2024-08-23T21:06:40Z)
# Issue #25712: Ollama (Partner package) and cache integration not working correctly - missing filters / Community Package works (关闭时间 2024-08-23T20:38:28Z)
# Issue #25710: ai21: address breaking changes in sdk 2.14.0 [wip]
#  (关闭时间 2024-08-23T21:17:49Z)
# Issue #25709: infra: reenable min version testing 2, ci ignore ai21 (关闭时间 2024-08-23T23:28:42Z)
# Issue #25708: Revert "infra: reenable min version testing" (关闭时间 2024-08-23T17:20:23Z)
# Issue #25707: community: remove unused verify_ssl kwarg from aiohttp request (关闭时间 2024-08-23T17:14:05Z)
# Issue #25706: text-splitters[patch]: fix typing for `keep_separator` (关闭时间 2024-08-23T17:22:03Z)
# Issue #25705: infra: gitignore api_ref mds (关闭时间 2024-08-23T16:50:30Z)
# Issue #25699: box: fix bugs in docs (关闭时间 2024-08-23T19:36:24Z)
# Issue #25689: core: mmr util (关闭时间 2024-08-23T04:31:17Z)
# Issue #25686: infra: xfail pydantic v2 arg to py function (关闭时间 2024-08-22T23:52:57Z)
# Issue #25683: Remove Warning (关闭时间 2024-08-22T23:10:35Z)
# Issue #25679: docs: api ref to new site somewheres (关闭时间 2024-08-23T17:01:16Z)
# Issue #25678: docs: api ref to new site links in featuretable (关闭时间 2024-08-22T21:52:51Z)
# Issue #25677: standard-tests[patch]: test Message.name (关闭时间 2024-08-22T21:47:31Z)
# Issue #25673: fix typo (关闭时间 2024-08-22T17:33:54Z)
# Issue #25672: cli: release 0.0.30 (关闭时间 2024-08-22T17:21:19Z)
# Issue #25671: community: Give more context on DeepInfra 500 errors (关闭时间 2024-08-22T17:10:51Z)
# Issue #25669: docs: Add ChatZhipuAI tool calling and structured output docstring (关闭时间 2024-08-22T14:34:41Z)
# Issue #25665: update_readme (关闭时间 2024-08-22T13:18:33Z)
# Issue #25663: community: add metadata filter to CassandraGraphVectorStore (关闭时间 2024-08-22T18:27:17Z)
# Issue #25662: Doc[Embeddings] Add docs for `ZhipuAIEmbeddings` (关闭时间 2024-08-23T01:33:43Z)
# Issue #25660: community: add retry for session expired exception in neo4j (关闭时间 2024-08-22T13:07:36Z)
# Issue #25658: community: Dynamodb history messages key (关闭时间 2024-08-23T08:05:29Z)
# Issue #25649: docs: Change Pull Request to Merge Request in GitLab notebook (关闭时间 2024-08-22T17:15:45Z)
# Issue #25648: databricks: add vector search and embeddings (关闭时间 2024-08-24T00:40:21Z)
# Issue #25647: docs: Updated WikipediaLoader documentation (关闭时间 2024-08-23T08:19:04Z)

# %% [markdown]
# ## 优化导出文件管理
#
# 考虑到 GitHubSentinel 项目长期运行将会生成一大批项目进展文件，因此将所有进展文件统一存储在`daily_progress` 目录下，并按照 `{owners}_{repo}/{since_day}_{until_day}.md` 方式命名。
#
# 如下所示：
#
# ```shell
# daily_progress
# ├── langchain-ai_langchain
# │   ├── 2024-08-04.md
# │   ├── 2024-08-04_report.md
# │   ├── 2024-08-18.md
# │   └── 2024-08-18_report.md
# ├── llm_logs.log
# ├── ollama_ollama
# │   ├── 2024-07-30_to_2024-08-04.md
# │   ├── 2024-07-30_to_2024-08-04_report.md
# │   ├── 2024-08-02_to_2024-08-04.md
# │   ├── 2024-08-02_to_2024-08-04_report.md
# │   ├── 2024-08-04.md
# │   └── 2024-08-04_report.md
# ```

# %%
github_client.export_progress_by_date_range(repo='langchain-ai/langchain', days=3)
# Out:
# 2024-08-25T14:43:11.938131+0800 INFO Exported time-range progress to daily_progress/langchain-ai_langchain/2024-08-22_to_2024-08-25.md
# 'daily_progress/langchain-ai_langchain/2024-08-22_to_2024-08-25.md'

# %%
github_client.export_daily_progress(repo='langchain-ai/langchain')
# Out:
# 2024-08-25T14:43:17.083143+0800 INFO Exported daily progress to daily_progress/langchain-ai_langchain/2024-08-25.md
# 'daily_progress/langchain-ai_langchain/2024-08-25.md'

# %% [markdown]
# ### Homework: 尝试扩展 GitHubClient，使其支持 Until 参数条件筛选
